# %%
import pandas as pd
import string
import nltk
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
import ray
import numpy as np
from os import cpu_count

# %%
from string import digits
_remove_digits = str.maketrans('', '', digits)

STEMMER = PorterStemmer()

# %%
corpus_path = '../corpus/reuters_corpus.csv'

# %%
corpus_df = pd.read_csv(corpus_path, names=['doc_id', 'title', 'content', 'topics'], 
                dtype=str, 
                na_filter=False, 
                index_col=False)

# %%
corpus_df['topics'] = \
    corpus_df['topics'].apply(lambda x: x.replace('[', '').replace(']','').replace("'", '').replace(',',' '))

# %%
chunks = np.array_split(corpus_df, cpu_count())

# %%
def _process(s):
    s = s.replace('\n', ' ')
    s = s.replace('.', '')
    s = s.replace('-', ' ')
    s = s.replace("'s", '')
    s = s.translate(_remove_digits)
    translator = str.maketrans(string.punctuation, ' '*len(string.punctuation))
    s = s.lower().strip().translate(translator)
    tmp = ' '.join(STEMMER.stem(x) for x in s.split() if x not in nltk.corpus.stopwords.words('english'))
    return tmp

@ray.remote
def worker(df_chunk):
    df_chunk['content'] = df_chunk['content'].apply(lambda x: _process(x))
    df_chunk['title'] = df_chunk['title'].apply(lambda x: _process(x))
    df_chunk['merged'] = df_chunk['title'] + ' ' + df_chunk['content']
    df_chunk.drop(columns=['title', 'content'], inplace=True)
    return df_chunk

# %%
ray.init(num_cpus=cpu_count())
input = [ray.put(chunk) for chunk in chunks]
r = ray.get([worker.remote(c) for c in input])
ray.shutdown()

# corpus_df['content'] = corpus_df['content'].apply(lambda x: _process(x))
# corpus_df['title'] = corpus_df['title'].apply(lambda x: _process(x))

# corpus_df['merged'] = corpus_df['title'] + ' ' + corpus_df['content']
# corpus_df.drop(columns=['title', 'content'], inplace=True)
# Out:
# 2020-03-10 17:31:32,943	INFO resource_spec.py:212 -- Starting Ray with 2.49 GiB memory available for workers and up to 1.26 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-03-10 17:31:33,350	INFO services.py:1078 -- View the Ray dashboard at localhost:8265

# %%
corpus_df = pd.concat(r, axis=0)

# %%
topics_dict = {} # k: doc_id, v: [topics]

# %%
# find out those have multiple topics
corpus_df['has_multiple_topics'] = corpus_df['topics'].apply(lambda x: True if (len(x.split()) >= 2) else False)

tmp = []
# handle multiple topics
def f(row):
    topics = row['topics'].split()
    topics_dict[row['doc_id']] = topics
    if row['has_multiple_topics']:
        for topic in topics:
            new_df = pd.DataFrame([[row['doc_id'], topic, row['merged']]], columns=['doc_id','topics','merged'])
            tmp.append(new_df)

corpus_df.apply(lambda x: f(x), axis=1)

corpus_df.drop(corpus_df[corpus_df['has_multiple_topics']].index, inplace=True)
corpus_df.drop(columns=['has_multiple_topics'], inplace=True)

df_ = pd.concat(tmp)
corpus_df = pd.concat([corpus_df, df_])

# %%
training = corpus_df[corpus_df['topics'] != '']
to_do = corpus_df[corpus_df['topics'] == '']

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(training['merged'])
y = training['topics'].to_numpy()

from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier()
neigh.fit(X, y)

X2 = vectorizer.transform(to_do['merged'])

# %%
prediction_df = pd.DataFrame(neigh.kneighbors(X2, n_neighbors=2)[1], columns=['topic1', 'topic2'], dtype=int)

prediction_df.reset_index(drop=True, inplace=True)
to_do.reset_index(drop=True, inplace=True)

to_do = pd.concat([prediction_df, to_do], axis=1)

# %%
def i2topic(i):
    return y[i]

def f2(row):
    topic1 = i2topic(row['topic1'])
    topic2 = i2topic(row['topic2'])
    topics_dict[row['doc_id']] = list(set([topic1, topic2]))

to_do.apply(lambda x: f2(x), axis=1)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 10206    None
# 10207    None
# 10208    None
# 10209    None
# 10210    None
# Length: 10211, dtype: object

# %%
topic_index = {}

def update_topic_index(topic, doc_id):
    if topic in topic_index.keys():
        topics_dict[topic].append(doc_id)
    else:
        topics_dict[topic] = [doc_id]

for doc_id, topics in topic_dict.items():
    for topic in topics:
        update_topic_index(topic=topic, doc_id=doc_id)

# %%
with open('../../corpus/topic.idx', 'wb') as f:
    pickle.dump(topic_index, f)

# %%
topic_index
# Out:
# {'cocoa': ['1',
#   '275',
#   '318',
#   '1730',
#   '2521',
#   '3012',
#   '3190',
#   '3225',
#   '3310',
#   '3815',
#   '4147',
#   '4470',
#   '4793',
#   '5103',
#   '5168',
#   '5192',
#   '5258',
#   '5382',
#   '5491',
#   '5598',
#   '5880',
#   '6128',
#   '6405',
#   '6407',
#   '6414',
#   '6493',
#   '6544',
#   '7071',
#   '7311',
#   '7613',
#   '8326',
#   '8850',
#   '8961',
#   '8978',
#   '9307',
#   '9450',
#   '9559',
#   '9719',
#   '9903',
#   '9950',
#   '9953',
#   '10014',
#   '10122',
#   '10403',
#   '10449',
#   '10471',
#   '10491',
#   '10505',
#   '10506',
#   '10584',
#   '10586',
#   '10613',
#   '10619',
#   '10742',
#   '10760',
#   '10995',
#   '11186',
#   '11224',
#   '11341',
#   '11459',
#   '11462',
#   '11780',
#   '11811',
#   '11843',
#   '12401',
#   '12763',
#   '12813',
#   '13271',
#   '13462',
#   '13606',
#   '13722',
#   '13993',
#   '14332',
#   '14343',
#   '14699',
#   '15095',
#   '15139',
#   '15179',
#   '15653',
#   '16098',
#   '16148',
#   '16748',
#   '17407',
#   '17499',
#   '17568',
#   '17664',
#   '17707',
#   '17733',
#   '17803',
#   '17942',
#   '17984',
#   '18014',
#   '18056',
#   '18221',
#   '18222',
#   '18383',
#   '18395',
#   '18397',
#   '18690',
#   '18775',
#   '19358',
#   '19500',
#   '19570',
#   '19637',
#   '20005'],
#  'acq': ['2',
#   '3',
#   '4',
#   '7',
#   '10',
#   '12',
#   '15',
#   '16',
#   '17',
#   '21',
#   '25',
#   '33',
#   '34',
#   '39',
#   '44',
#   '45',
#   '68',
#   '70',
#   '73',
#   '79',
#   '88',
#   '90',
#   '96',
#   '110',
#   '112',
#   '114',
#   '116',
#   '117',
#   '118',
#   '119',
#   '120',
#   '122',
#   '125',
#   '128',
#   '131',
#   '134',
#   '135',
#   '148',
#   '149',
#   '150',
#   '153',
#   '154',
#   '156',
#   '157',
#   '162',
#   '170',
#   '172',
#   '177',
#   '184',
#   '185',
#   '186',
#   '195',
#   '199',
#   '205',
#   '206',
#   '207',
#   '215',
#   '219',
#   '226',
#   '230',
#   '240',
#   '243',
#   '245',
#   '251',
#   '255',
#   '260',
#   '262',
#   '264',
#   '266',
#   '269',
#   '280',
#   '282',
#   '288',
#   '294',
#   '295',
#   '298',
#   '301',
#   '302',
#   '304',
#   '306',
#   '315',
#   '316',
#   '318',
#   '321',
#   '324',
#   '331',
#   '334',
#   '344',
#   '347',
#   '360',
#   '361',
#   '362',
#   '365',
#   '366',
#   '367',
#   '369',
#   '371',
#   '372',
#   '375',
#   '376',
#   '379',
#   '380',
#   '382',
#   '383',
#   '384',
#   '385',
#   '387',
#   '389',
#   '393',
#   '397',
#   '398',
#   '400',
#   '401',
#   '408',
#   '412',
#   '418',
#   '424',
#   '426',
#   '428',
#   '436',
#   '437',
#   '440',
#   '441',
#   '442',
#   '446',
#   '447',
#   '448',
#   '451',
#   '463',
#   '467',
#   '469',
#   '471',
#   '473',
#   '474',
#   '476',
#   '477',
#   '478',
#   '479',
#   '482',
#   '487',
#   '492',
#   '493',
#   '496',
#   '497',
#   '498',
#   '499',
#   '500',
#   '503',
#   '504',
#   '505',
#   '507',
#   '510',
#   '515',
#   '520',
#   '523',
#   '532',
#   '545',
#   '547',
#   '549',
#   '550',
#   '551',
#   '553',
#   '556',
#   '558',
#   '559',
#   '561',
#   '563',
#   '564',
#   '566',
#   '568',
#   '570',
#   '583',
#   '584',
#   '585',
#   '587',
#   '589',
#   '602',
#   '604',
#   '609',
#   '616',
#   '623',
#   '627',
#   '629',
#   '631',
#   '641',
#   '647',
#   '651',
#   '653',
#   '654',
#   '655',
#   '657',
#   '658',
#   '659',
#   '660',
#   '661',
#   '662',
#   '666',
#   '667',
#   '669',
#   '671',
#   '672',
#   '676',
#   '679',
#   '681',
#   '682',
#   '683',
#   '703',
#   '706',
#   '709',
#   '712',
#   '714',
#   '719',
#   '721',
#   '724',
#   '725',
#   '727',
#   '729',
#   '730',
#   '732',
#   '733',
#   '735',
#   '736',
#   '737',
#   '738',
#   '741',
#   '745',
#   '747',
#   '748',
#   '749',
#   '751',
#   '752',
#   '753',
#   '755',
#   '757',
#   '762',
#   '763',
#   '764',
#   '766',
#   '767',
#   '768',
#   '775',
#   '782',
#   '784',
#   '786',
#   '787',
#   '788',
#   '794',
#   '795',
#   '797',
#   '801',
#   '805',
#   '806',
#   '807',
#   '809',
#   '813',
#   '814',
#   '819',
#   '820',
#   '821',
#   '823',
#   '824',
#   '825',
#   '832',
#   '836',
#   '838',
#   '840',
#   '844',
#   '845',
#   '847',
#   '849',
#   '850',
#   '851',
#   '853',
#   '858',
#   '863',
#   '876',
#   '878',
#   '881',
#   '882',
#   '888',
#   '904',
#   '927',
#   '932',
#   '939',
#   '941',
#   '951',
#   '957',
#   '960',
#   '961',
#   '963',
#   '967',
#   '970',
#   '978',
#   '979',
#   '982',
#   '985',
#   '990',
#   '996',
#   '997',
#   '1000',
#   '1001',
#   '1006',
#   '1018',
#   '1020',
#   '1021',
#   '1029',
#   '1031',
#   '1032',
#   '1034',
#   '1037',
#   '1038',
#   '1039',
#   '1041',
#   '1045',
#   '1046',
#   '1048',
#   '1051',
#   '1060',
#   '1061',
#   '1062',
#   '1064',
#   '1073',
#   '1074',
#   '1075',
#   '1076',
#   '1083',
#   '1098',
#   '1099',
#   '1103',
#   '1104',
#   '1115',
#   '1116',
#   '1118',
#   '1123',
#   '1144',
#   '1146',
#   '1149',
#   '1150',
#   '1153',
#   '1159',
#   '1161',
#   '1164',
#   '1168',
#   '1186',
#   '1187',
#   '1189',
#   '1195',
#   '1203',
#   '1209',
#   '1213',
#   '1214',
#   '1217',
#   '1218',
#   '1219',
#   '1220',
#   '1223',
#   '1227',
#   '1228',
#   '1232',
#   '1233',
#   '1237',
#   '1238',
#   '1241',
#   '1243',
#   '1254',
#   '1261',
#   '1262',
#   '1267',
#   '1270',
#   '1275',
#   '1276',
#   '1278',
#   '1279',
#   '1280',
#   '1281',
#   '1282',
#   '1289',
#   '1291',
#   '1292',
#   '1294',
#   '1297',
#   '1302',
#   '1303',
#   '1310',
#   '1316',
#   '1318',
#   '1321',
#   '1330',
#   '1334',
#   '1336',
#   '1340',
#   '1348',
#   '1352',
#   '1354',
#   '1365',
#   '1371',
#   '1373',
#   '1374',
#   '1386',
#   '1389',
#   '1390',
#   '1392',
#   '1397',
#   '1403',
#   '1408',
#   '1409',
#   '1412',
#   '1415',
#   '1418',
#   '1419',
#   '1422',
#   '1425',
#   '1426',
#   '1429',
#   '1430',
#   '1431',
#   '1432',
#   '1441',
#   '1450',
#   '1455',
#   '1463',
#   '1465',
#   '1473',
#   '1477',
#   '1479',
#   '1480',
#   '1484',
#   '1485',
#   '1486',
#   '1490',
#   '1491',
#   '1497',
#   '1500',
#   '1504',
#   '1505',
#   '1506',
#   '1507',
#   '1509',
#   '1511',
#   '1512',
#   '1518',
#   '1522',
#   '1531',
#   '1534',
#   '1542',
#   '1558',
#   '1562',
#   '1573',
#   '1577',
#   '1578',
#   '1580',
#   '1581',
#   '1584',
#   '1595',
#   '1596',
#   '1597',
#   '1600',
#   '1601',
#   '1606',
#   '1609',
#   '1614',
#   '1622',
#   '1624',
#   '1626',
#   '1628',
#   '1630',
#   '1632',
#   '1634',
#   '1635',
#   '1636',
#   '1645',
#   '1647',
#   '1649',
#   '1654',
#   '1659',
#   '1663',
#   '1664',
#   '1665',
#   '1666',
#   '1667',
#   '1668',
#   '1670',
#   '1671',
#   '1673',
#   '1676',
#   '1678',
#   '1679',
#   '1684',
#   '1687',
#   '1690',
#   '1693',
#   '1694',
#   '1695',
#   '1697',
#   '1700',
#   '1702',
#   '1703',
#   '1719',
#   '1720',
#   '1721',
#   '1726',
#   '1729',
#   '1733',
#   '1735',
#   '1736',
#   '1737',
#   '1739',
#   '1740',
#   '1741',
#   '1742',
#   '1743',
#   '1745',
#   '1748',
#   '1753',
#   '1754',
#   '1755',
#   '1760',
#   '1766',
#   '1771',
#   '1775',
#   '1778',
#   '1781',
#   '1787',
#   '1788',
#   '1789',
#   '1790',
#   '1791',
#   '1796',
#   '1798',
#   '1801',
#   '1808',
#   '1817',
#   '1818',
#   '1819',
#   '1825',
#   '1826',
#   '1830',
#   '1835',
#   '1836',
#   '1847',
#   '1850',
#   '1855',
#   '1860',
#   '1862',
#   '1870',
#   '1874',
#   '1884',
#   '1886',
#   '1891',
#   '1900',
#   '1905',
#   '1920',
#   '1922',
#   '1935',
#   '1937',
#   '1947',
#   '1974',
#   '1981',
#   '1987',
#   '1989',
#   '1991',
#   '1994',
#   '1996',
#   '1998',
#   '2009',
#   '2010',
#   '2013',
#   '2017',
#   '2024',
#   '2027',
#   '2036',
#   '2039',
#   '2045',
#   '2054',
#   '2057',
#   '2058',
#   '2067',
#   '2071',
#   '2075',
#   '2076',
#   '2077',
#   '2080',
#   '2081',
#   '2090',
#   '2091',
#   '2097',
#   '2100',
#   '2102',
#   '2107',
#   '2114',
#   '2118',
#   '2120',
#   '2126',
#   '2127',
#   '2128',
#   '2129',
#   '2131',
#   '2134',
#   '2138',
#   '2147',
#   '2150',
#   '2151',
#   '2152',
#   '2159',
#   '2160',
#   '2165',
#   '2177',
#   '2184',
#   '2189',
#   '2192',
#   '2193',
#   '2195',
#   '2199',
#   '2201',
#   '2202',
#   '2204',
#   '2207',
#   '2208',
#   '2209',
#   '2210',
#   '2218',
#   '2219',
#   '2220',
#   '2224',
#   '2225',
#   '2233',
#   '2237',
#   '2240',
#   '2241',
#   '2244',
#   '2247',
#   '2248',
#   '2250',
#   '2251',
#   '2255',
#   '2256',
#   '2257',
#   '2267',
#   '2268',
#   '2271',
#   '2277',
#   '2281',
#   '2282',
#   '2283',
#   '2284',
#   '2287',
#   '2289',
#   '2291',
#   '2295',
#   '2297',
#   '2299',
#   '2301',
#   '2305',
#   '2306',
#   '2315',
#   '2318',
#   '2321',
#   '2322',
#   '2323',
#   '2325',
#   '2329',
#   '2331',
#   '2334',
#   '2344',
#   '2345',
#   '2349',
#   '2356',
#   '2360',
#   '2362',
#   '2365',
#   '2368',
#   '2369',
#   '2373',
#   '2374',
#   '2375',
#   '2376',
#   '2387',
#   '2392',
#   '2395',
#   '2399',
#   '2400',
#   '2410',
#   '2413',
#   '2419',
#   '2422',
#   '2427',
#   '2430',
#   '2431',
#   '2432',
#   '2434',
#   '2438',
#   '2444',
#   '2445',
#   '2446',
#   '2447',
#   '2450',
#   '2451',
#   '2453',
#   '2454',
#   '2455',
#   '2461',
#   '2462',
#   '2464',
#   '2469',
#   '2470',
#   '2472',
#   '2473',
#   '2474',
#   '2475',
#   '2476',
#   '2481',
#   '2485',
#   '2491',
#   '2497',
#   '2500',
#   '2502',
#   '2505',
#   '2506',
#   '2509',
#   '2510',
#   '2512',
#   '2520',
#   '2523',
#   '2526',
#   '2528',
#   '2532',
#   '2533',
#   '2534',
#   '2536',
#   '2538',
#   '2540',
#   '2543',
#   '2545',
#   '2546',
#   '2547',
#   '2551',
#   '2552',
#   '2564',
#   '2570',
#   '2573',
#   '2574',
#   '2577',
#   '2578',
#   '2582',
#   '2583',
#   '2589',
#   '2596',
#   '2597',
#   '2603',
#   '2604',
#   '2605',
#   '2609',
#   '2612',
#   '2614',
#   '2627',
#   '2628',
#   '2629',
#   '2631',
#   '2634',
#   '2636',
#   '2637',
#   '2638',
#   '2641',
#   '2647',
#   '2650',
#   '2652',
#   '2654',
#   '2660',
#   '2661',
#   '2665',
#   '2668',
#   '2669',
#   '2670',
#   '2672',
#   '2673',
#   '2676',
#   '2682',
#   '2685',
#   '2690',
#   '2692',
#   '2699',
#   '2701',
#   '2702',
#   '2706',
#   '2714',
#   '2716',
#   '2717',
#   '2719',
#   '2721',
#   '2728',
#   '2730',
#   '2732',
#   '2733',
#   '2734',
#   '2735',
#   '2736',
#   '2737',
#   '2738',
#   '2739',
#   '2740',
#   '2745',
#   '2759',
#   '2763',
#   '2766',
#   '2768',
#   '2769',
#   '2778',
#   '2783',
#   '2784',
#   '2791',
#   '2794',
#   '2795',
#   '2798',
#   '2799',
#   '2802',
#   '2805',
#   '2808',
#   '2810',
#   '2811',
#   '2812',
#   '2813',
#   '2814',
#   '2815',
#   '2818',
#   '2829',
#   '2831',
#   '2833',
#   '2840',
#   '2841',
#   '2844',
#   '2846',
#   '2847',
#   '2854',
#   '2859',
#   '2860',
#   '2861',
#   '2863',
#   '2865',
#   '2867',
#   '2868',
#   '2871',
#   '2874',
#   '2879',
#   '2882',
#   '2884',
#   '2885',
#   '2889',
#   '2896',
#   '2897',
#   '2898',
#   '2902',
#   '2903',
#   '2904',
#   '2907',
#   '2909',
#   '2910',
#   '2911',
#   '2914',
#   '2917',
#   '2924',
#   '2926',
#   '2927',
#   '2933',
#   '2934',
#   '2939',
#   '2940',
#   '2941',
#   '2945',
#   '2946',
#   '2948',
#   '2950',
#   '2951',
#   '2953',
#   '2956',
#   '2967',
#   '2972',
#   '2981',
#   '2986',
#   '2988',
#   '2999',
#   '3000',
#   '3004',
#   '3009',
#   '3013',
#   '3014',
#   '3018',
#   '3021',
#   '3023',
#   '3025',
#   '3027',
#   '3033',
#   '3035',
#   '3038',
#   '3039',
#   '3041',
#   '3042',
#   '3052',
#   '3053',
#   '3054',
#   '3056',
#   '3058',
#   '3061',
#   '3063',
#   '3066',
#   '3069',
#   '3071',
#   '3072',
#   '3074',
#   '3075',
#   '3081',
#   '3083',
#   '3085',
#   '3086',
#   '3089',
#   '3093',
#   '3094',
#   '3095',
#   '3096',
#   '3097',
#   '3100',
#   '3101',
#   '3106',
#   '3107',
#   '3108',
#   '3114',
#   '3119',
#   '3120',
#   '3123',
#   '3125',
#   '3129',
#   '3130',
#   '3139',
#   '3142',
#   '3148',
#   '3151',
#   '3152',
#   '3153',
#   '3154',
#   '3157',
#   '3158',
#   '3166',
#   '3168',
#   '3170',
#   '3172',
#   '3174',
#   '3175',
#   '3176',
#   '3177',
#   '3178',
#   '3179',
#   '3180',
#   '3182',
#   '3184',
#   '3186',
#   '3188',
#   '3196',
#   '3198',
#   '3205',
#   '3208',
#   '3209',
#   '3212',
#   '3213',
#   '3216',
#   '3223',
#   '3229',
#   '3230',
#   '3233',
#   '3235',
#   '3237',
#   '3238',
#   '3239',
#   '3240',
#   '3241',
#   '3242',
#   '3244',
#   '3248',
#   '3250',
#   '3251',
#   '3252',
#   '3255',
#   '3261',
#   '3262',
#   '3263',
#   '3264',
#   '3265',
#   '3266',
#   '3267',
#   '3276',
#   '3277',
#   '3284',
#   '3286',
#   '3287',
#   '3290',
#   '3295',
#   '3297',
#   '3298',
#   '3300',
#   '3301',
#   '3302',
#   '3305',
#   ...],
#  'money-supply': ['3',
#   '8',
#   '20',
#   '30',
#   '31',
#   '52',
#   '58',
#   '60',
#   '62',
#   '63',
#   '67',
#   '76',
#   '77',
#   '78',
#   '80',
#   '81',
#   '92',
#   '94',
#   '95',
#   '99',
#   '100',
#   '101',
#   '102',
#   '103',
#   '109',
#   '111',
#   '118',
#   '132',
#   '133',
#   '155',
#   '158',
#   '159',
#   '171',
#   '173',
#   '198',
#   '203',
#   '204',
#   '207',
#   '216',
#   '220',
#   '222',
#   '239',
#   '250',
#   '255',
#   '261',
#   '265',
#   '277',
#   '289',
#   '294',
#   '319',
#   '321',
#   '330',
#   '333',
#   '337',
#   '363',
#   '373',
#   '403',
#   '445',
#   '454',
#   '460',
#   '465',
#   '472',
#   '527',
#   '565',
#   '590',
#   '593',
#   '600',
#   '607',
#   '608',
#   '611',
#   '632',
#   '636',
#   '639',
#   '643',
#   '645',
#   '648',
#   '663',
#   '664',
#   '665',
#   '667',
#   '673',
#   '675',
#   '713',
#   '750',
#   '760',
#   '761',
#   '763',
#   '765',
#   '771',
#   '782',
#   '790',
#   '792',
#   '795',
#   '796',
#   '803',
#   '810',
#   '815',
#   '826',
#   '830',
#   '831',
#   '839',
#   '860',
#   '869',
#   '876',
#   '892',
#   '907',
#   '912',
#   '940',
#   '946',
#   '948',
#   '961',
#   '973',
#   '992',
#   '993',
#   '994',
#   '997',
#   '1004',
#   '1025',
#   '1028',
#   '1051',
#   '1053',
#   '1055',
#   '1092',
#   '1093',
#   '1107',
#   '1130',
#   '1145',
#   '1146',
#   '1161',
#   '1162',
#   '1165',
#   '1166',
#   '1171',
#   '1175',
#   '1180',
#   '1183',
#   '1196',
#   '1202',
#   '1204',
#   '1206',
#   '1222',
#   '1224',
#   '1232',
#   '1235',
#   '1236',
#   '1240',
#   '1247',
#   '1249',
#   '1250',
#   '1253',
#   '1256',
#   '1274',
#   '1286',
#   '1296',
#   '1305',
#   '1307',
#   '1308',
#   '1309',
#   '1319',
#   '1323',
#   '1325',
#   '1333',
#   '1334',
#   '1346',
#   '1368',
#   '1410',
#   '1411',
#   '1437',
#   '1441',
#   '1447',
#   '1451',
#   '1458',
#   '1462',
#   '1464',
#   '1470',
#   '1474',
#   '1476',
#   '1487',
#   '1489',
#   '1504',
#   '1515',
#   '1517',
#   '1530',
#   '1538',
#   '1547',
#   '1548',
#   '1549',
#   '1551',
#   '1559',
#   '1561',
#   '1565',
#   '1573',
#   '1589',
#   '1592',
#   '1593',
#   '1609',
#   '1612',
#   '1613',
#   '1615',
#   '1668',
#   '1669',
#   '1683',
#   '1698',
#   '1699',
#   '1707',
#   '1710',
#   '1713',
#   '1717',
#   '1728',
#   '1737',
#   '1744',
#   '1748',
#   '1757',
#   '1762',
#   '1774',
#   '1776',
#   '1780',
#   '1782',
#   '1795',
#   '1805',
#   '1810',
#   '1813',
#   '1823',
#   '1828',
#   '1829',
#   '1841',
#   '1859',
#   '1866',
#   '1870',
#   '1888',
#   '1894',
#   '1898',
#   '1912',
#   '1933',
#   '1939',
#   '1956',
#   '1962',
#   '1969',
#   '1979',
#   '1985',
#   '1988',
#   '2002',
#   '2014',
#   '2015',
#   '2018',
#   '2021',
#   '2023',
#   '2032',
#   '2037',
#   '2038',
#   '2041',
#   '2043',
#   '2059',
#   '2060',
#   '2069',
#   '2093',
#   '2103',
#   '2105',
#   '2113',
#   '2123',
#   '2124',
#   '2125',
#   '2131',
#   '2132',
#   '2135',
#   '2139',
#   '2141',
#   '2144',
#   '2145',
#   '2146',
#   '2222',
#   '2229',
#   '2255',
#   '2262',
#   '2263',
#   '2267',
#   '2292',
#   '2294',
#   '2311',
#   '2313',
#   '2314',
#   '2319',
#   '2328',
#   '2330',
#   '2334',
#   '2343',
#   '2355',
#   '2356',
#   '2363',
#   '2372',
#   '2378',
#   '2401',
#   '2403',
#   '2414',
#   '2424',
#   '2431',
#   '2439',
#   '2441',
#   '2442',
#   '2446',
#   '2457',
#   '2465',
#   '2466',
#   '2468',
#   '2503',
#   '2516',
#   '2537',
#   '2554',
#   '2563',
#   '2571',
#   '2581',
#   '2586',
#   '2588',
#   '2607',
#   '2616',
#   '2621',
#   '2624',
#   '2640',
#   '2644',
#   '2675',
#   '2686',
#   '2698',
#   '2703',
#   '2705',
#   '2726',
#   '2743',
#   '2744',
#   '2755',
#   '2770',
#   '2786',
#   '2790',
#   '2795',
#   '2804',
#   '2816',
#   '2823',
#   '2835',
#   '2845',
#   '2858',
#   '2869',
#   '2870',
#   '2872',
#   '2875',
#   '2876',
#   '2885',
#   '2893',
#   '2901',
#   '2921',
#   '2941',
#   '2943',
#   '2949',
#   '2967',
#   '2984',
#   '2987',
#   '2994',
#   '3022',
#   '3049',
#   '3050',
#   '3055',
#   '3058',
#   '3073',
#   '3081',
#   '3090',
#   '3099',
#   '3101',
#   '3102',
#   '3113',
#   '3126',
#   '3127',
#   '3141',
#   '3143',
#   '3144',
#   '3165',
#   '3167',
#   '3201',
#   '3203',
#   '3224',
#   '3226',
#   '3234',
#   '3236',
#   '3240',
#   '3246',
#   '3265',
#   '3274',
#   '3280',
#   '3281',
#   '3288',
#   '3289',
#   '3291',
#   '3297',
#   '3304',
#   '3307',
#   '3319',
#   '3348',
#   '3355',
#   '3362',
#   '3375',
#   '3412',
#   '3465',
#   '3485',
#   '3518',
#   '3522',
#   '3524',
#   '3544',
#   '3550',
#   '3576',
#   '3608',
#   '3614',
#   '3627',
#   '3650',
#   '3653',
#   '3657',
#   '3658',
#   '3661',
#   '3671',
#   '3678',
#   '3679',
#   '3715',
#   '3719',
#   '3733',
#   '3745',
#   '3749',
#   '3753',
#   '3754',
#   '3756',
#   '3767',
#   '3773',
#   '3776',
#   '3794',
#   '3799',
#   '3804',
#   '3814',
#   '3824',
#   '3826',
#   '3836',
#   '3844',
#   '3848',
#   '3863',
#   '3866',
#   '3880',
#   '3889',
#   '3911',
#   '3927',
#   '3930',
#   '3947',
#   '3956',
#   '3963',
#   '3978',
#   '3988',
#   '4002',
#   '4013',
#   '4020',
#   '4034',
#   '4046',
#   '4050',
#   '4053',
#   '4110',
#   '4124',
#   '4163',
#   '4181',
#   '4190',
#   '4195',
#   '4207',
#   '4211',
#   '4234',
#   '4242',
#   '4247',
#   '4248',
#   '4250',
#   '4251',
#   '4265',
#   '4268',
#   '4287',
#   '4311',
#   '4316',
#   '4321',
#   '4322',
#   '4325',
#   '4329',
#   '4334',
#   '4359',
#   '4362',
#   '4379',
#   '4390',
#   '4403',
#   '4413',
#   '4415',
#   '4417',
#   '4418',
#   '4435',
#   '4442',
#   '4463',
#   '4469',
#   '4479',
#   '4482',
#   '4487',
#   '4508',
#   '4515',
#   '4516',
#   '4519',
#   '4530',
#   '4531',
#   '4532',
#   '4533',
#   '4534',
#   '4538',
#   '4544',
#   '4545',
#   '4559',
#   '4561',
#   '4565',
#   '4580',
#   '4602',
#   '4618',
#   '4624',
#   '4627',
#   '4639',
#   '4653',
#   '4673',
#   '4686',
#   '4701',
#   '4721',
#   '4722',
#   '4723',
#   '4730',
#   '4731',
#   '4738',
#   '4752',
#   '4757',
#   '4762',
#   '4786',
#   '4790',
#   '4799',
#   '4815',
#   '4826',
#   '4828',
#   '4836',
#   '4840',
#   '4854',
#   '4858',
#   '4859',
#   '4862',
#   '4865',
#   '4880',
#   '4888',
#   '4913',
#   '4916',
#   '4924',
#   '4928',
#   '4929',
#   '4938',
#   '4945',
#   '4949',
#   '4950',
#   '4961',
#   '4967',
#   '4971',
#   '4975',
#   '4977',
#   '4979',
#   '4992',
#   '5000',
#   '5019',
#   '5024',
#   '5025',
#   '5028',
#   '5036',
#   '5038',
#   '5045',
#   '5047',
#   '5049',
#   '5059',
#   '5060',
#   '5067',
#   '5079',
#   '5096',
#   '5110',
#   '5133',
#   '5136',
#   '5165',
#   '5173',
#   '5174',
#   '5187',
#   '5207',
#   '5233',
#   '5246',
#   '5251',
#   '5253',
#   '5275',
#   '5289',
#   '5305',
#   '5324',
#   '5337',
#   '5343',
#   '5364',
#   '5365',
#   '5369',
#   '5370',
#   '5395',
#   '5399',
#   '5418',
#   '5420',
#   '5430',
#   '5457',
#   '5478',
#   '5479',
#   '5504',
#   '5510',
#   '5519',
#   '5536',
#   '5584',
#   '5588',
#   '5601',
#   '5607',
#   '5614',
#   '5618',
#   '5619',
#   '5621',
#   '5633',
#   '5638',
#   '5651',
#   '5666',
#   '5676',
#   '5685',
#   '5695',
#   '5698',
#   '5714',
#   '5726',
#   '5730',
#   '5733',
#   '5736',
#   '5745',
#   '5747',
#   '5770',
#   '5775',
#   '5781',
#   '5782',
#   '5784',
#   '5795',
#   '5797',
#   '5798',
#   '5820',
#   '5834',
#   '5836',
#   '5846',
#   '5857',
#   '5863',
#   '5867',
#   '5871',
#   '5872',
#   '5877',
#   '5878',
#   '5893',
#   '5897',
#   '5907',
#   '5942',
#   '5959',
#   '5970',
#   '5971',
#   '5983',
#   '5987',
#   '5989',
#   '5992',
#   '5995',
#   '5999',
#   '6004',
#   '6012',
#   '6015',
#   '6019',
#   '6029',
#   '6053',
#   '6057',
#   '6071',
#   '6077',
#   '6100',
#   '6131',
#   '6133',
#   '6140',
#   '6141',
#   '6148',
#   '6156',
#   '6160',
#   '6161',
#   '6167',
#   '6168',
#   '6170',
#   '6183',
#   '6193',
#   '6206',
#   '6258',
#   '6263',
#   '6268',
#   '6272',
#   '6291',
#   '6303',
#   '6336',
#   '6345',
#   '6390',
#   '6391',
#   '6403',
#   '6423',
#   '6424',
#   '6439',
#   '6444',
#   '6470',
#   '6482',
#   '6530',
#   '6536',
#   '6555',
#   '6569',
#   '6579',
#   '6580',
#   '6582',
#   '6587',
#   '6615',
#   '6619',
#   '6625',
#   '6628',
#   '6631',
#   '6643',
#   '6645',
#   '6648',
#   '6678',
#   '6690',
#   '6691',
#   '6700',
#   '6715',
#   '6727',
#   '6754',
#   '6766',
#   '6769',
#   '6781',
#   '6782',
#   '6786',
#   '6792',
#   '6803',
#   '6808',
#   '6820',
#   '6822',
#   '6832',
#   '6834',
#   '6835',
#   '6838',
#   '6847',
#   '6851',
#   '6868',
#   '6900',
#   '6901',
#   '6904',
#   '6919',
#   '6937',
#   '6938',
#   '6948',
#   '6970',
#   '6971',
#   '6978',
#   '6980',
#   '6987',
#   '6988',
#   '7007',
#   '7009',
#   '7012',
#   '7014',
#   '7025',
#   '7028',
#   '7029',
#   '7035',
#   '7036',
#   '7044',
#   '7089',
#   '7116',
#   '7121',
#   '7125',
#   '7127',
#   '7131',
#   '7142',
#   '7147',
#   '7153',
#   '7165',
#   '7176',
#   '7180',
#   '7183',
#   '7197',
#   '7198',
#   '7201',
#   '7202',
#   '7206',
#   '7213',
#   '7214',
#   '7224',
#   '7231',
#   '7232',
#   '7233',
#   '7239',
#   '7241',
#   '7248',
#   '7249',
#   '7257',
#   '7262',
#   '7269',
#   '7281',
#   '7282',
#   '7283',
#   '7284',
#   '7285',
#   '7295',
#   '7298',
#   '7299',
#   '7300',
#   '7303',
#   '7313',
#   '7324',
#   '7325',
#   '7345',
#   '7347',
#   '7374',
#   '7378',
#   '7392',
#   '7411',
#   '7416',
#   '7417',
#   '7419',
#   '7420',
#   '7421',
#   '7422',
#   '7425',
#   '7426',
#   '7428',
#   '7436',
#   '7437',
#   '7440',
#   '7478',
#   '7479',
#   '7485',
#   '7493',
#   '7499',
#   '7506',
#   '7507',
#   '7511',
#   '7522',
#   '7523',
#   '7526',
#   '7532',
#   '7542',
#   '7546',
#   '7550',
#   '7554',
#   '7555',
#   '7556',
#   '7575',
#   '7587',
#   '7594',
#   '7597',
#   '7616',
#   '7624',
#   '7653',
#   '7658',
#   '7668',
#   '7674',
#   '7683',
#   '7688',
#   '7692',
#   '7699',
#   '7718',
#   '7719',
#   '7720',
#   '7751',
#   '7754',
#   '7758',
#   '7767',
#   '7772',
#   '7780',
#   '7783',
#   '7786',
#   '7788',
#   '7794',
#   '7798',
#   '7807',
#   '7818',
#   '7833',
#   '7844',
#   '7863',
#   '7882',
#   '7885',
#   '7889',
#   '7906',
#   '7909',
#   '7910',
#   '7911',
#   '7915',
#   '7919',
#   '7923',
#   '7929',
#   '7971',
#   '7976',
#   '7978',
#   '7980',
#   '7982',
#   '7986',
#   '7989',
#   '8031',
#   '8037',
#   '8042',
#   '8062',
#   '8104',
#   '8122',
#   '8129',
#   '8152',
#   '8154',
#   '8165',
#   '8181',
#   '8215',
#   '8232',
#   '8233',
#   '8235',
#   '8237',
#   '8249',
#   '8251',
#   '8260',
#   '8263',
#   '8266',
#   '8268',
#   '8277',
#   '8278',
#   '8284',
#   '8303',
#   '8304',
#   '8305',
#   '8321',
#   '8323',
#   '8324',
#   '8325',
#   '8329',
#   '8332',
#   '8348',
#   '8362',
#   '8365',
#   '8377',
#   '8385',
#   '8390',
#   '8393',
#   '8398',
#   '8419',
#   '8420',
#   '8431',
#   '8442',
#   '8452',
#   '8455',
#   '8456',
#   '8460',
#   '8463',
#   '8464',
#   '8466',
#   '8473',
#   '8474',
#   '8492',
#   '8498',
#   '8507',
#   '8515',
#   '8517',
#   '8519',
#   '8524',
#   '8537',
#   '8549',
#   '8552',
#   '8560',
#   '8583',
#   '8620',
#   '8631',
#   '8634',
#   '8636',
#   '8640',
#   '8646',
#   '8655',
#   '8660',
#   '8695',
#   '8703',
#   '8720',
#   '8723',
#   '8727',
#   '8737',
#   '8762',
#   '8775',
#   '8779',
#   '8783',
#   '8787',
#   '8789',
#   '8790',
#   '8801',
#   '8807',
#   '8813',
#   '8816',
#   '8817',
#   '8833',
#   '8842',
#   '8847',
#   '8870',
#   '8878',
#   '8889',
#   '8891',
#   '8897',
#   ...],
#  'earn': ['4',
#   '9',
#   '11',
#   '12',
#   '13',
#   '14',
#   '16',
#   '18',
#   '23',
#   '24',
#   '27',
#   '35',
#   '36',
#   '37',
#   '38',
#   '40',
#   '41',
#   '43',
#   '50',
#   '53',
#   '56',
#   '64',
#   '65',
#   '66',
#   '70',
#   '71',
#   '72',
#   '73',
#   '74',
#   '79',
#   '82',
#   '83',
#   '84',
#   '85',
#   '86',
#   '87',
#   '89',
#   '91',
#   '93',
#   '98',
#   '108',
#   '113',
#   '115',
#   '117',
#   '120',
#   '123',
#   '126',
#   '129',
#   '130',
#   '138',
#   '139',
#   '140',
#   '142',
#   '143',
#   '145',
#   '146',
#   '147',
#   '151',
#   '152',
#   '160',
#   '163',
#   '164',
#   '165',
#   '166',
#   '167',
#   '168',
#   '169',
#   '183',
#   '187',
#   '192',
#   '196',
#   '201',
#   '202',
#   '210',
#   '212',
#   '214',
#   '277',
#   '279',
#   '299',
#   '305',
#   '317',
#   '328',
#   '339',
#   '345',
#   '355',
#   '356',
#   '375',
#   '378',
#   '381',
#   '388',
#   '390',
#   '391',
#   '392',
#   '396',
#   '399',
#   '404',
#   '405',
#   '406',
#   '407',
#   '409',
#   '410',
#   '413',
#   '420',
#   '422',
#   '423',
#   '435',
#   '438',
#   '439',
#   '449',
#   '455',
#   '456',
#   '457',
#   '461',
#   '464',
#   '466',
#   '468',
#   '470',
#   '473',
#   '479',
#   '480',
#   '481',
#   '483',
#   '484',
#   '490',
#   '493',
#   '494',
#   '500',
#   '506',
#   '508',
#   '509',
#   '512',
#   '513',
#   '514',
#   '517',
#   '521',
#   '523',
#   '524',
#   '528',
#   '529',
#   '530',
#   '531',
#   '533',
#   '534',
#   '535',
#   '536',
#   '537',
#   '538',
#   '539',
#   '541',
#   '546',
#   '548',
#   '552',
#   '554',
#   '555',
#   '557',
#   '560',
#   '561',
#   '566',
#   '569',
#   '571',
#   '572',
#   '573',
#   '574',
#   '575',
#   '576',
#   '577',
#   '578',
#   '579',
#   '580',
#   '581',
#   '585',
#   '586',
#   '588',
#   '591',
#   '592',
#   '594',
#   '595',
#   '596',
#   '598',
#   '599',
#   '601',
#   '602',
#   '603',
#   '605',
#   '606',
#   '610',
#   '612',
#   '613',
#   '614',
#   '615',
#   '617',
#   '618',
#   '619',
#   '620',
#   '621',
#   '624',
#   '625',
#   '631',
#   '633',
#   '637',
#   '638',
#   '640',
#   '642',
#   '644',
#   '646',
#   '649',
#   '651',
#   '654',
#   '662',
#   '670',
#   '674',
#   '680',
#   '683',
#   '686',
#   '687',
#   '689',
#   '690',
#   '691',
#   '692',
#   '693',
#   '695',
#   '696',
#   '698',
#   '699',
#   '700',
#   '701',
#   '702',
#   '705',
#   '707',
#   '715',
#   '717',
#   '722',
#   '723',
#   '726',
#   '728',
#   '730',
#   '731',
#   '734',
#   '737',
#   '739',
#   '743',
#   '744',
#   '753',
#   '756',
#   '758',
#   '770',
#   '773',
#   '774',
#   '776',
#   '777',
#   '778',
#   '779',
#   '780',
#   '781',
#   '783',
#   '785',
#   '799',
#   '803',
#   '806',
#   '807',
#   '811',
#   '812',
#   '813',
#   '817',
#   '818',
#   '824',
#   '828',
#   '837',
#   '845',
#   '846',
#   '847',
#   '848',
#   '852',
#   '859',
#   '861',
#   '864',
#   '865',
#   '866',
#   '868',
#   '879',
#   '881',
#   '883',
#   '886',
#   '887',
#   '899',
#   '902',
#   '920',
#   '921',
#   '922',
#   '927',
#   '928',
#   '936',
#   '938',
#   '949',
#   '951',
#   '958',
#   '967',
#   '968',
#   '970',
#   '971',
#   '976',
#   '981',
#   '983',
#   '984',
#   '986',
#   '988',
#   '995',
#   '998',
#   '1003',
#   '1005',
#   '1007',
#   '1009',
#   '1010',
#   '1011',
#   '1013',
#   '1015',
#   '1016',
#   '1017',
#   '1019',
#   '1024',
#   '1027',
#   '1033',
#   '1038',
#   '1044',
#   '1046',
#   '1047',
#   '1059',
#   '1062',
#   '1063',
#   '1065',
#   '1066',
#   '1070',
#   '1071',
#   '1080',
#   '1081',
#   '1084',
#   '1087',
#   '1090',
#   '1091',
#   '1096',
#   '1101',
#   '1105',
#   '1108',
#   '1109',
#   '1111',
#   '1113',
#   '1114',
#   '1115',
#   '1117',
#   '1119',
#   '1121',
#   '1122',
#   '1124',
#   '1126',
#   '1127',
#   '1128',
#   '1132',
#   '1134',
#   '1135',
#   '1136',
#   '1137',
#   '1138',
#   '1143',
#   '1152',
#   '1157',
#   '1160',
#   '1167',
#   '1169',
#   '1170',
#   '1173',
#   '1176',
#   '1177',
#   '1178',
#   '1179',
#   '1181',
#   '1182',
#   '1188',
#   '1189',
#   '1191',
#   '1192',
#   '1193',
#   '1198',
#   '1200',
#   '1205',
#   '1208',
#   '1221',
#   '1225',
#   '1229',
#   '1234',
#   '1239',
#   '1240',
#   '1242',
#   '1244',
#   '1245',
#   '1249',
#   '1251',
#   '1252',
#   '1255',
#   '1258',
#   '1260',
#   '1262',
#   '1264',
#   '1265',
#   '1269',
#   '1271',
#   '1277',
#   '1283',
#   '1284',
#   '1285',
#   '1287',
#   '1288',
#   '1293',
#   '1297',
#   '1298',
#   '1301',
#   '1311',
#   '1313',
#   '1314',
#   '1315',
#   '1317',
#   '1320',
#   '1322',
#   '1323',
#   '1326',
#   '1327',
#   '1328',
#   '1329',
#   '1339',
#   '1341',
#   '1342',
#   '1344',
#   '1345',
#   '1351',
#   '1353',
#   '1355',
#   '1358',
#   '1359',
#   '1360',
#   '1363',
#   '1364',
#   '1366',
#   '1367',
#   '1370',
#   '1373',
#   '1375',
#   '1376',
#   '1378',
#   '1379',
#   '1380',
#   '1381',
#   '1382',
#   '1384',
#   '1390',
#   '1391',
#   '1401',
#   '1404',
#   '1408',
#   '1414',
#   '1415',
#   '1417',
#   '1420',
#   '1426',
#   '1428',
#   '1433',
#   '1434',
#   '1435',
#   '1438',
#   '1442',
#   '1445',
#   '1446',
#   '1448',
#   '1449',
#   '1452',
#   '1455',
#   '1456',
#   '1460',
#   '1461',
#   '1466',
#   '1467',
#   '1468',
#   '1469',
#   '1471',
#   '1474',
#   '1483',
#   '1484',
#   '1485',
#   '1488',
#   '1492',
#   '1494',
#   '1496',
#   '1498',
#   '1501',
#   '1502',
#   '1507',
#   '1508',
#   '1511',
#   '1522',
#   '1523',
#   '1524',
#   '1525',
#   '1526',
#   '1527',
#   '1528',
#   '1529',
#   '1532',
#   '1534',
#   '1536',
#   '1539',
#   '1541',
#   '1543',
#   '1545',
#   '1546',
#   '1554',
#   '1555',
#   '1563',
#   '1564',
#   '1566',
#   '1567',
#   '1568',
#   '1569',
#   '1571',
#   '1572',
#   '1575',
#   '1585',
#   '1586',
#   '1596',
#   '1602',
#   '1603',
#   '1604',
#   '1605',
#   '1608',
#   '1610',
#   '1614',
#   '1618',
#   '1620',
#   '1624',
#   '1633',
#   '1638',
#   '1639',
#   '1642',
#   '1643',
#   '1644',
#   '1645',
#   '1648',
#   '1650',
#   '1651',
#   '1653',
#   '1655',
#   '1657',
#   '1658',
#   '1662',
#   '1663',
#   '1664',
#   '1669',
#   '1670',
#   '1672',
#   '1677',
#   '1682',
#   '1685',
#   '1687',
#   '1688',
#   '1689',
#   '1696',
#   '1701',
#   '1703',
#   '1705',
#   '1706',
#   '1707',
#   '1708',
#   '1714',
#   '1716',
#   '1718',
#   '1722',
#   '1726',
#   '1727',
#   '1732',
#   '1734',
#   '1742',
#   '1747',
#   '1749',
#   '1751',
#   '1752',
#   '1753',
#   '1758',
#   '1759',
#   '1763',
#   '1764',
#   '1765',
#   '1767',
#   '1768',
#   '1769',
#   '1779',
#   '1781',
#   '1783',
#   '1784',
#   '1788',
#   '1794',
#   '1797',
#   '1803',
#   '1804',
#   '1814',
#   '1816',
#   '1820',
#   '1821',
#   '1824',
#   '1837',
#   '1840',
#   '1844',
#   '1846',
#   '1849',
#   '1852',
#   '1853',
#   '1854',
#   '1860',
#   '1861',
#   '1872',
#   '1873',
#   '1877',
#   '1893',
#   '1917',
#   '1919',
#   '1923',
#   '1924',
#   '1941',
#   '1945',
#   '1972',
#   '1984',
#   '1991',
#   '1993',
#   '1997',
#   '2001',
#   '2005',
#   '2009',
#   '2016',
#   '2017',
#   '2020',
#   '2021',
#   '2023',
#   '2026',
#   '2028',
#   '2029',
#   '2031',
#   '2033',
#   '2035',
#   '2042',
#   '2045',
#   '2047',
#   '2048',
#   '2049',
#   '2050',
#   '2051',
#   '2053',
#   '2055',
#   '2056',
#   '2060',
#   '2061',
#   '2062',
#   '2065',
#   '2069',
#   '2070',
#   '2071',
#   '2072',
#   '2075',
#   '2077',
#   '2079',
#   '2081',
#   '2082',
#   '2083',
#   '2084',
#   '2085',
#   '2089',
#   '2092',
#   '2099',
#   '2101',
#   '2104',
#   '2106',
#   '2108',
#   '2109',
#   '2111',
#   '2112',
#   '2116',
#   '2122',
#   '2130',
#   '2133',
#   '2136',
#   '2137',
#   '2142',
#   '2144',
#   '2148',
#   '2149',
#   '2153',
#   '2154',
#   '2157',
#   '2160',
#   '2162',
#   '2163',
#   '2166',
#   '2167',
#   '2173',
#   '2176',
#   '2180',
#   '2182',
#   '2185',
#   '2188',
#   '2189',
#   '2193',
#   '2194',
#   '2196',
#   '2198',
#   '2203',
#   '2205',
#   '2208',
#   '2211',
#   '2212',
#   '2213',
#   '2215',
#   '2216',
#   '2221',
#   '2227',
#   '2230',
#   '2233',
#   '2234',
#   '2235',
#   '2236',
#   '2238',
#   '2243',
#   '2249',
#   '2252',
#   '2253',
#   '2258',
#   '2259',
#   '2260',
#   '2261',
#   '2265',
#   '2266',
#   '2270',
#   '2273',
#   '2274',
#   '2275',
#   '2276',
#   '2279',
#   '2283',
#   '2287',
#   '2289',
#   '2290',
#   '2293',
#   '2296',
#   '2298',
#   '2303',
#   '2304',
#   '2306',
#   '2307',
#   '2308',
#   '2309',
#   '2312',
#   '2316',
#   '2320',
#   '2321',
#   '2329',
#   '2332',
#   '2333',
#   '2335',
#   '2337',
#   '2338',
#   '2339',
#   '2340',
#   '2342',
#   '2345',
#   '2346',
#   '2347',
#   '2348',
#   '2350',
#   '2351',
#   '2353',
#   '2357',
#   '2361',
#   '2362',
#   '2366',
#   '2368',
#   '2370',
#   '2372',
#   '2377',
#   '2379',
#   '2380',
#   '2385',
#   '2386',
#   '2391',
#   '2393',
#   '2396',
#   '2397',
#   '2398',
#   '2402',
#   '2405',
#   '2409',
#   '2415',
#   '2416',
#   '2421',
#   '2422',
#   '2426',
#   '2428',
#   '2429',
#   '2433',
#   '2435',
#   '2437',
#   '2438',
#   '2440',
#   '2443',
#   '2451',
#   '2454',
#   '2458',
#   '2459',
#   '2460',
#   '2463',
#   '2464',
#   '2471',
#   '2477',
#   '2478',
#   '2479',
#   '2482',
#   '2483',
#   '2484',
#   '2486',
#   '2487',
#   '2488',
#   '2490',
#   '2492',
#   '2494',
#   '2496',
#   '2504',
#   '2513',
#   '2518',
#   '2519',
#   '2525',
#   '2527',
#   '2536',
#   '2539',
#   '2544',
#   '2548',
#   '2549',
#   '2558',
#   '2560',
#   '2561',
#   '2562',
#   '2566',
#   '2567',
#   '2568',
#   '2569',
#   '2575',
#   '2579',
#   '2580',
#   '2584',
#   '2587',
#   '2590',
#   '2591',
#   '2593',
#   '2598',
#   '2602',
#   '2608',
#   '2611',
#   '2613',
#   '2619',
#   '2630',
#   '2640',
#   '2642',
#   '2644',
#   '2645',
#   '2649',
#   '2651',
#   '2653',
#   '2656',
#   '2657',
#   '2658',
#   '2659',
#   '2663',
#   '2664',
#   '2666',
#   '2667',
#   '2671',
#   '2673',
#   '2674',
#   '2676',
#   '2677',
#   '2679',
#   '2680',
#   '2685',
#   '2687',
#   '2689',
#   '2691',
#   '2692',
#   '2693',
#   '2695',
#   '2700',
#   '2701',
#   '2708',
#   '2710',
#   '2711',
#   '2712',
#   '2713',
#   '2718',
#   '2720',
#   '2722',
#   '2723',
#   '2724',
#   '2729',
#   '2742',
#   '2748',
#   '2750',
#   '2751',
#   '2752',
#   '2753',
#   '2754',
#   '2756',
#   '2757',
#   '2758',
#   '2761',
#   '2770',
#   '2771',
#   '2772',
#   '2773',
#   '2779',
#   '2780',
#   '2781',
#   '2787',
#   '2789',
#   '2792',
#   '2797',
#   '2800',
#   '2801',
#   '2803',
#   '2806',
#   '2807',
#   '2809',
#   '2812',
#   '2820',
#   '2821',
#   '2825',
#   '2826',
#   '2827',
#   '2829',
#   '2830',
#   '2834',
#   '2836',
#   '2839',
#   '2849',
#   '2850',
#   '2852',
#   '2855',
#   '2856',
#   '2861',
#   '2863',
#   '2865',
#   '2866',
#   '2873',
#   '2877',
#   '2883',
#   '2886',
#   '2887',
#   '2888',
#   '2889',
#   '2890',
#   '2891',
#   '2895',
#   '2903',
#   '2905',
#   '2908',
#   '2912',
#   '2915',
#   '2916',
#   '2918',
#   '2919',
#   '2920',
#   '2928',
#   '2929',
#   '2930',
#   '2931',
#   '2935',
#   '2938',
#   '2960',
#   '2961',
#   '2962',
#   '2963',
#   '2972',
#   '3005',
#   '3008',
#   '3011',
#   '3026',
#   '3030',
#   '3037',
#   '3059',
#   '3062',
#   '3077',
#   '3080',
#   '3090',
#   '3091',
#   '3112',
#   '3117',
#   '3118',
#   '3119',
#   '3151',
#   '3156',
#   ...],
#  'grain': ['5',
#   '6',
#   '19',
#   '32',
#   '43',
#   '51',
#   '55',
#   '57',
#   '97',
#   '106',
#   '124',
#   '136',
#   '180',
#   '193',
#   '197',
#   '228',
#   '235',
#   '241',
#   '253',
#   '254',
#   '258',
#   '280',
#   '285',
#   '327',
#   '395',
#   '417',
#   '425',
#   '429',
#   '476',
#   '501',
#   '516',
#   '622',
#   '634',
#   '694',
#   '742',
#   '822',
#   '855',
#   '856',
#   '862',
#   '871',
#   '874',
#   '934',
#   '959',
#   '1057',
#   '1067',
#   '1069',
#   '1094',
#   '1131',
#   '1185',
#   '1215',
#   '1231',
#   '1257',
#   '1268',
#   '1273',
#   '1295',
#   '1299',
#   '1369',
#   '1377',
#   '1388',
#   '1395',
#   '1396',
#   '1399',
#   '1405',
#   '1406',
#   '1416',
#   '1439',
#   '1482',
#   '1516',
#   '1551',
#   '1557',
#   '1570',
#   '1582',
#   '1590',
#   '1623',
#   '1631',
#   '1640',
#   '1652',
#   '1674',
#   '1731',
#   '1777',
#   '1792',
#   '1827',
#   '1843',
#   '1845',
#   '1868',
#   '1876',
#   '1882',
#   '1883',
#   '1901',
#   '1903',
#   '1907',
#   '1915',
#   '1952',
#   '1970',
#   '1979',
#   '2003',
#   '2008',
#   '2018',
#   '2044',
#   '2068',
#   '2074',
#   '2095',
#   '2117',
#   '2169',
#   '2171',
#   '2172',
#   '2183',
#   '2191',
#   '2217',
#   '2223',
#   '2232',
#   '2264',
#   '2364',
#   '2367',
#   '2382',
#   '2425',
#   '2436',
#   '2456',
#   '2508',
#   '2514',
#   '2524',
#   '2535',
#   '2595',
#   '2599',
#   '2617',
#   '2727',
#   '2741',
#   '2747',
#   '2749',
#   '2777',
#   '2848',
#   '2857',
#   '2864',
#   '2882',
#   '2913',
#   '2922',
#   '2947',
#   '2975',
#   '3082',
#   '3084',
#   '3132',
#   '3138',
#   '3191',
#   '3272',
#   '3282',
#   '3289',
#   '3299',
#   '3306',
#   '3311',
#   '3312',
#   '3314',
#   '3323',
#   '3324',
#   '3330',
#   '3334',
#   '3335',
#   '3337',
#   '3358',
#   '3386',
#   '3390',
#   '3401',
#   '3408',
#   '3429',
#   '3445',
#   '3581',
#   '3737',
#   '3847',
#   '3855',
#   '3881',
#   '3897',
#   '3904',
#   '3913',
#   '3929',
#   '3949',
#   '3979',
#   '3981',
#   '4044',
#   '4047',
#   '4057',
#   '4077',
#   '4133',
#   '4200',
#   '4203',
#   '4208',
#   '4278',
#   '4280',
#   '4289',
#   '4296',
#   '4314',
#   '4356',
#   '4381',
#   '4382',
#   '4432',
#   '4444',
#   '4473',
#   '4478',
#   '4490',
#   '4502',
#   '4524',
#   '4540',
#   '4549',
#   '4599',
#   '4637',
#   '4655',
#   '4671',
#   '4678',
#   '4696',
#   '4719',
#   '4736',
#   '4778',
#   '4825',
#   '4860',
#   '4905',
#   '4939',
#   '4946',
#   '4984',
#   '4988',
#   '5003',
#   '5017',
#   '5033',
#   '5056',
#   '5109',
#   '5170',
#   '5184',
#   '5185',
#   '5224',
#   '5262',
#   '5266',
#   '5338',
#   '5363',
#   '5383',
#   '5408',
#   '5467',
#   '5518',
#   '5531',
#   '5606',
#   '5610',
#   '5611',
#   '5636',
#   '5637',
#   '5639',
#   '5640',
#   '5648',
#   '5800',
#   '5826',
#   '5847',
#   '5892',
#   '5920',
#   '5933',
#   '5972',
#   '6006',
#   '6079',
#   '6081',
#   '6114',
#   '6127',
#   '6142',
#   '6153',
#   '6209',
#   '6221',
#   '6236',
#   '6251',
#   '6253',
#   '6259',
#   '6265',
#   '6267',
#   '6269',
#   '6296',
#   '6326',
#   '6339',
#   '6386',
#   '6513',
#   '6585',
#   '6588',
#   '6589',
#   '6608',
#   '6624',
#   '6626',
#   '6634',
#   '6720',
#   '6735',
#   '6744',
#   '6751',
#   '6882',
#   '6890',
#   '6897',
#   '6898',
#   '6903',
#   '6909',
#   '6915',
#   '6921',
#   '6946',
#   '6960',
#   '6989',
#   '7062',
#   '7103',
#   '7154',
#   '7160',
#   '7205',
#   '7215',
#   '7238',
#   '7326',
#   '7336',
#   '7387',
#   '7389',
#   '7390',
#   '7393',
#   '7395',
#   '7418',
#   '7471',
#   '7545',
#   '7565',
#   '7579',
#   '7700',
#   '7753',
#   '7792',
#   '7829',
#   '7917',
#   '7934',
#   '7943',
#   '7957',
#   '8003',
#   '8004',
#   '8006',
#   '8009',
#   '8061',
#   '8076',
#   '8116',
#   '8132',
#   '8140',
#   '8157',
#   '8161',
#   '8164',
#   '8166',
#   '8179',
#   '8213',
#   '8257',
#   '8273',
#   '8319',
#   '8374',
#   '8400',
#   '8413',
#   '8443',
#   '8446',
#   '8535',
#   '8604',
#   '8613',
#   '8656',
#   '8686',
#   '8759',
#   '8800',
#   '8828',
#   '8881',
#   '8895',
#   '8941',
#   '8943',
#   '8983',
#   '8993',
#   '9018',
#   '9021',
#   '9058',
#   '9093',
#   '9094',
#   '9095',
#   '9145',
#   '9154',
#   '9254',
#   '9298',
#   '9323',
#   '9406',
#   '9470',
#   '9521',
#   '9523',
#   '9660',
#   '9667',
#   '9688',
#   '9696',
#   '9702',
#   '9705',
#   '9772',
#   '9773',
#   '9782',
#   '9786',
#   '9793',
#   '9843',
#   '9865',
#   '9907',
#   '9958',
#   '9989',
#   '10082',
#   '10120',
#   '10124',
#   '10139',
#   '10164',
#   '10172',
#   '10175',
#   '10195',
#   '10239',
#   '10268',
#   '10305',
#   '10319',
#   '10325',
#   '10339',
#   '10380',
#   '10406',
#   '10444',
#   '10487',
#   '10489',
#   '10494',
#   '10517',
#   '10519',
#   '10525',
#   '10569',
#   '10643',
#   '10670',
#   '10701',
#   '10830',
#   '10882',
#   '10956',
#   '11012',
#   '11023',
#   '11040',
#   '11065',
#   '11082',
#   '11084',
#   '11085',
#   '11091',
#   '11119',
#   '11178',
#   '11208',
#   '11216',
#   '11224',
#   '11250',
#   '11269',
#   '11316',
#   '11343',
#   '11380',
#   '11392',
#   '11399',
#   '11415',
#   '11427',
#   '11436',
#   '11445',
#   '11536',
#   '11607',
#   '11608',
#   '11610',
#   '11612',
#   '11640',
#   '11645',
#   '11655',
#   '11671',
#   '11678',
#   '11694',
#   '11729',
#   '11739',
#   '11768',
#   '11769',
#   '11815',
#   '11834',
#   '11840',
#   '11862',
#   '11865',
#   '11885',
#   '11886',
#   '11911',
#   '11917',
#   '11936',
#   '11939',
#   '11955',
#   '11964',
#   '12002',
#   '12009',
#   '12023',
#   '12051',
#   '12052',
#   '12055',
#   '12081',
#   '12158',
#   '12160',
#   '12161',
#   '12192',
#   '12254',
#   '12261',
#   '12269',
#   '12311',
#   '12323',
#   '12325',
#   '12327',
#   '12338',
#   '12359',
#   '12366',
#   '12372',
#   '12373',
#   '12381',
#   '12417',
#   '12420',
#   '12428',
#   '12436',
#   '12458',
#   '12500',
#   '12543',
#   '12552',
#   '12583',
#   '12587',
#   '12615',
#   '12638',
#   '12675',
#   '12695',
#   '12709',
#   '12711',
#   '12713',
#   '12720',
#   '12723',
#   '12726',
#   '12750',
#   '12762',
#   '12764',
#   '12768',
#   '12802',
#   '12830',
#   '12849',
#   '12872',
#   '12879',
#   '12887',
#   '12936',
#   '12968',
#   '12971',
#   '13067',
#   '13070',
#   '13094',
#   '13097',
#   '13099',
#   '13120',
#   '13123',
#   '13129',
#   '13162',
#   '13169',
#   '13173',
#   '13179',
#   '13272',
#   '13277',
#   '13294',
#   '13313',
#   '13319',
#   '13366',
#   '13434',
#   '13458',
#   '13546',
#   '13636',
#   '13729',
#   '13795',
#   '13799',
#   '13803',
#   '13807',
#   '13814',
#   '13828',
#   '13832',
#   '13851',
#   '13852',
#   '13856',
#   '13878',
#   '13942',
#   '13990',
#   '14042',
#   '14062',
#   '14068',
#   '14081',
#   '14126',
#   '14132',
#   '14157',
#   '14212',
#   '14230',
#   '14252',
#   '14301',
#   '14313',
#   '14330',
#   '14340',
#   '14360',
#   '14389',
#   '14408',
#   '14437',
#   '14444',
#   '14447',
#   '14448',
#   '14451',
#   '14453',
#   '14457',
#   '14460',
#   '14464',
#   '14467',
#   '14483',
#   '14486',
#   '14487',
#   '14491',
#   '14509',
#   '14515',
#   '14518',
#   '14520',
#   '14614',
#   '14671',
#   '14675',
#   '14688',
#   '14701',
#   '14702',
#   '14706',
#   '14718',
#   '14721',
#   '14722',
#   '14797',
#   '14828',
#   '14832',
#   '14841',
#   '14858',
#   '14864',
#   '14914',
#   '14950',
#   '15033',
#   '15043',
#   '15097',
#   '15106',
#   '15132',
#   '15137',
#   '15165',
#   '15186',
#   '15224',
#   '15271',
#   '15273',
#   '15287',
#   '15303',
#   '15323',
#   '15341',
#   '15367',
#   '15388',
#   '15472',
#   '15480',
#   '15500',
#   '15531',
#   '15567',
#   '15572',
#   '15580',
#   '15582',
#   '15618',
#   '15648',
#   '15649',
#   '15676',
#   '15686',
#   '15710',
#   '15720',
#   '15726',
#   '15728',
#   '15836',
#   '15842',
#   '15844',
#   '15845',
#   '15853',
#   '15856',
#   '15860',
#   '15863',
#   '15864',
#   '15866',
#   '15868',
#   '15869',
#   '15870',
#   '15871',
#   '15874',
#   '15875',
#   '15877',
#   '15890',
#   '15893',
#   '15895',
#   '15904',
#   '15906',
#   '15910',
#   '15911',
#   '15914',
#   '15916',
#   '15917',
#   '15927',
#   '15928',
#   '15942',
#   '15952',
#   '15975',
#   '15999',
#   '16009',
#   '16012',
#   '16014',
#   '16039',
#   '16071',
#   '16079',
#   '16099',
#   '16144',
#   '16147',
#   '16218',
#   '16254',
#   '16265',
#   '16271',
#   '16359',
#   '16525',
#   '16601',
#   '16624',
#   '16751',
#   '16753',
#   '16763',
#   '16765',
#   '16782',
#   '16790',
#   '16899',
#   '16936',
#   '16943',
#   '16947',
#   '16960',
#   '16974',
#   '17010',
#   '17022',
#   '17057',
#   '17092',
#   '17139',
#   '17145',
#   '17153',
#   '17167',
#   '17179',
#   '17183',
#   '17198',
#   '17203',
#   '17215',
#   '17235',
#   '17257',
#   '17280',
#   '17286',
#   '17312',
#   '17323',
#   '17332',
#   '17350',
#   '17351',
#   '17356',
#   '17366',
#   '17378',
#   '17380',
#   '17383',
#   '17386',
#   '17393',
#   '17398',
#   '17426',
#   '17443',
#   '17503',
#   '17509',
#   '17514',
#   '17521',
#   '17572',
#   '17662',
#   '17722',
#   '17755',
#   '17767',
#   '17769',
#   '17955',
#   '17962',
#   '18006',
#   '18024',
#   '18035',
#   '18046',
#   '18263',
#   '18275',
#   '18297',
#   '18306',
#   '18345',
#   '18377',
#   '18400',
#   '18408',
#   '18409',
#   '18413',
#   '18460',
#   '18482',
#   '18529',
#   '18609',
#   '18614',
#   '18642',
#   '18656',
#   '18899',
#   '18908',
#   '18954',
#   '18973',
#   '19055',
#   '19059',
#   '19165',
#   '19169',
#   '19213',
#   '19275',
#   '19322',
#   '19388',
#   '19502',
#   '19549',
#   '19614',
#   '19668',
#   '19721',
#   '19729',
#   '19821',
#   '19835',
#   '19877',
#   '19931',
#   '19947',
#   '19964',
#   '19979',
#   '20018',
#   '20042',
#   '20052',
#   '20231',
#   '20239',
#   '20250',
#   '20258',
#   '20366',
#   '20511',
#   '20550',
#   '20594',
#   '20611',
#   '20637',
#   '20645',
#   '20649',
#   '20723',
#   '20738',
#   '20763',
#   '20864',
#   '20866',
#   '20873',
#   '20908',
#   '21090',
#   '21091',
#   '21123',
#   '21152',
#   '21168',
#   '21243',
#   '21368',
#   '21493',
#   '21530',
#   '21570'],
#  'wheat': ['5',
#   '6',
#   '19',
#   '32',
#   '55',
#   '97',
#   '180',
#   '235',
#   '241',
#   '253',
#   '254',
#   '258',
#   '285',
#   '395',
#   '425',
#   '501',
#   '694',
#   '742',
#   '856',
#   '871',
#   '874',
#   '1057',
#   '1067',
#   '1069',
#   '1094',
#   '1185',
#   '1231',
#   '1257',
#   '1295',
#   '1377',
#   '1385',
#   '1388',
#   '1396',
#   '1405',
#   '1416',
#   '1570',
#   '1590',
#   '1640',
#   '1674',
#   '1777',
#   '1792',
#   '1827',
#   '1901',
#   '1907',
#   '1970',
#   '2003',
#   '2008',
#   '2044',
#   '2074',
#   '2095',
#   '2169',
#   '2172',
#   '2191',
#   '2217',
#   '2223',
#   '2367',
#   '2382',
#   '2425',
#   '2508',
#   '2514',
#   '2524',
#   '2535',
#   '2741',
#   '2747',
#   '2857',
#   '2864',
#   '3132',
#   '3138',
#   '3272',
#   '3282',
#   '3299',
#   '3314',
#   '3323',
#   '3330',
#   '3334',
#   '3335',
#   '3358',
#   '3401',
#   '3429',
#   '3445',
#   '3546',
#   '3737',
#   '3897',
#   '3904',
#   '3913',
#   '4057',
#   '4077',
#   '4203',
#   '4278',
#   '4296',
#   '4356',
#   '4382',
#   '4473',
#   '4478',
#   '4490',
#   '4502',
#   '4549',
#   '4599',
#   '4655',
#   '4671',
#   '4696',
#   '4860',
#   '4946',
#   '5056',
#   '5262',
#   '5383',
#   '5467',
#   '5531',
#   '5606',
#   '5610',
#   '5636',
#   '5639',
#   '5648',
#   '6006',
#   '6079',
#   '6081',
#   '6114',
#   '6127',
#   '6153',
#   '6209',
#   '6221',
#   '6239',
#   '6259',
#   '6296',
#   '6326',
#   '6339',
#   '6608',
#   '6720',
#   '6744',
#   '6751',
#   '6882',
#   '6898',
#   '6903',
#   '6909',
#   '6915',
#   '6946',
#   '6960',
#   '7062',
#   '7205',
#   '7215',
#   '7238',
#   '7326',
#   '7418',
#   '7471',
#   '7545',
#   '7753',
#   '7829',
#   '7934',
#   '7957',
#   '8003',
#   '8006',
#   '8116',
#   '8157',
#   '8179',
#   '8273',
#   '8413',
#   '8535',
#   '8604',
#   '8759',
#   '8828',
#   '8993',
#   '9021',
#   '9095',
#   '9145',
#   '9660',
#   '9696',
#   '9708',
#   '9773',
#   '9782',
#   '9793',
#   '9843',
#   '9865',
#   '10120',
#   '10164',
#   '10172',
#   '10175',
#   '10195',
#   '10268',
#   '10305',
#   '10406',
#   '10444',
#   '10494',
#   '10519',
#   '10525',
#   '10569',
#   '10670',
#   '10830',
#   '10882',
#   '10956',
#   '11012',
#   '11023',
#   '11040',
#   '11085',
#   '11091',
#   '11119',
#   '11204',
#   '11208',
#   '11224',
#   '11250',
#   '11316',
#   '11343',
#   '11380',
#   '11392',
#   '11399',
#   '11415',
#   '11427',
#   '11445',
#   '11608',
#   '11610',
#   '11645',
#   '11655',
#   '11671',
#   '11678',
#   '11694',
#   '11815',
#   '11834',
#   '11865',
#   '11885',
#   '11886',
#   '12002',
#   '12009',
#   '12158',
#   '12192',
#   '12254',
#   '12261',
#   '12269',
#   '12325',
#   '12372',
#   '12420',
#   '12428',
#   '12458',
#   '12500',
#   '12543',
#   '12615',
#   '12638',
#   '12709',
#   '12711',
#   '12720',
#   '12723',
#   '12726',
#   '12762',
#   '12802',
#   '12887',
#   '12903',
#   '12971',
#   '13094',
#   '13097',
#   '13179',
#   '13272',
#   '13277',
#   '13313',
#   '13366',
#   '13434',
#   '13636',
#   '13729',
#   '13744',
#   '13799',
#   '13851',
#   '13852',
#   '13856',
#   '14081',
#   '14126',
#   '14157',
#   '14301',
#   '14408',
#   '14444',
#   '14457',
#   '14486',
#   '14491',
#   '14509',
#   '14614',
#   '14671',
#   '14675',
#   '14702',
#   '14718',
#   '14721',
#   '14722',
#   '14797',
#   '14841',
#   '14950',
#   '15043',
#   '15097',
#   '15132',
#   '15186',
#   '15271',
#   '15273',
#   '15341',
#   '15388',
#   '15472',
#   '15500',
#   '15567',
#   '15572',
#   '15582',
#   '15618',
#   '15676',
#   '15686',
#   '15728',
#   '15836',
#   '15845',
#   '15853',
#   '15860',
#   '15863',
#   '15864',
#   '15866',
#   '15868',
#   '15869',
#   '15870',
#   '15874',
#   '15875',
#   '15890',
#   '15893',
#   '15895',
#   '15906',
#   '15911',
#   '15916',
#   '15917',
#   '15927',
#   '15952',
#   '16071',
#   '16144',
#   '16218',
#   '16254',
#   '16271',
#   '16525',
#   '16782',
#   '16899',
#   '16974',
#   '17010',
#   '17022',
#   '17167',
#   '17179',
#   '17198',
#   '17235',
#   '17286',
#   '17312',
#   '17351',
#   '17356',
#   '17383',
#   '17398',
#   '17426',
#   '17503',
#   '17521',
#   '17662',
#   '17722',
#   '17755',
#   '17955',
#   '17962',
#   '18275',
#   '18297',
#   '18345',
#   '18377',
#   '18400',
#   '18413',
#   '18899',
#   '18908',
#   '19169',
#   '19213',
#   '19275',
#   '19322',
#   '19549',
#   '19614',
#   '19668',
#   '19821',
#   '19979',
#   '20231',
#   '20239',
#   '20258',
#   '20511',
#   '20550',
#   '20611',
#   '20645',
#   '20738',
#   '20908',
#   '21091',
#   '21243'],
#  'corn': ['5',
#   '6',
#   '51',
#   '57',
#   '97',
#   '193',
#   '197',
#   '235',
#   '327',
#   '395',
#   '429',
#   '501',
#   '516',
#   '622',
#   '634',
#   '694',
#   '855',
#   '934',
#   '1131',
#   '1215',
#   '1268',
#   '1273',
#   '1369',
#   '1385',
#   '1395',
#   '1399',
#   '1516',
#   '1582',
#   '1652',
#   '1777',
#   '1843',
#   '1876',
#   '1952',
#   '2044',
#   '2172',
#   '2183',
#   '2217',
#   '2264',
#   '2382',
#   '2436',
#   '2456',
#   '2595',
#   '2599',
#   '2617',
#   '2727',
#   '2741',
#   '2749',
#   '2777',
#   '2848',
#   '2913',
#   '2922',
#   '2947',
#   '3138',
#   '3191',
#   '3282',
#   '3299',
#   '3306',
#   '3330',
#   '3337',
#   '3358',
#   '3401',
#   '3429',
#   '3847',
#   '3855',
#   '3881',
#   '3949',
#   '3979',
#   '3981',
#   '4047',
#   '4133',
#   '4289',
#   '4296',
#   '4382',
#   '4490',
#   '4599',
#   '4825',
#   '4905',
#   '4939',
#   '4988',
#   '5003',
#   '5017',
#   '5033',
#   '5109',
#   '5185',
#   '5338',
#   '5467',
#   '5467',
#   '5518',
#   '5531',
#   '5606',
#   '5610',
#   '5636',
#   '5637',
#   '5847',
#   '5920',
#   '5933',
#   '6142',
#   '6221',
#   '6236',
#   '6239',
#   '6259',
#   '6269',
#   '6386',
#   '6585',
#   '6588',
#   '6735',
#   '6890',
#   '6897',
#   '7062',
#   '7205',
#   '7215',
#   '7336',
#   '7387',
#   '7389',
#   '7390',
#   '7395',
#   '7700',
#   '7792',
#   '7917',
#   '7934',
#   '7943',
#   '8004',
#   '8140',
#   '8161',
#   '8166',
#   '8257',
#   '8273',
#   '8400',
#   '8443',
#   '8446',
#   '8535',
#   '8759',
#   '8941',
#   '8983',
#   '8993',
#   '9058',
#   '9093',
#   '9094',
#   '9298',
#   '9323',
#   '9470',
#   '9521',
#   '9667',
#   '9865',
#   '9958',
#   '9989',
#   '10120',
#   '10139',
#   '10172',
#   '10175',
#   '10319',
#   '10339',
#   '10487',
#   '10489',
#   '10519',
#   '10701',
#   '10882',
#   '10956',
#   '11012',
#   '11082',
#   '11085',
#   '11091',
#   '11269',
#   '11392',
#   '11436',
#   '11607',
#   '11612',
#   '11729',
#   '11739',
#   '11769',
#   '11885',
#   '11936',
#   '11939',
#   '11964',
#   '12002',
#   '12052',
#   '12055',
#   '12160',
#   '12311',
#   '12323',
#   '12372',
#   '12417',
#   '12436',
#   '12500',
#   '12583',
#   '12587',
#   '12695',
#   '12709',
#   '12711',
#   '12713',
#   '12720',
#   '12750',
#   '12872',
#   '12879',
#   '12936',
#   '13173',
#   '13179',
#   '13319',
#   '13852',
#   '13856',
#   '14132',
#   '14252',
#   '14448',
#   '14460',
#   '14464',
#   '14467',
#   '14483',
#   '14832',
#   '14858',
#   '15033',
#   '15043',
#   '15106',
#   '15287',
#   '15323',
#   '15341',
#   '15480',
#   '15618',
#   '15648',
#   '15676',
#   '15686',
#   '15720',
#   '15845',
#   '15856',
#   '15860',
#   '15863',
#   '15871',
#   '15875',
#   '15877',
#   '15890',
#   '15904',
#   '15906',
#   '15910',
#   '15911',
#   '15917',
#   '15952',
#   '15999',
#   '16012',
#   '16071',
#   '16099',
#   '16147',
#   '16525',
#   '16624',
#   '16751',
#   '16765',
#   '17057',
#   '17092',
#   '17145',
#   '17153',
#   '17183',
#   '17312',
#   '17332',
#   '17350',
#   '17378',
#   '17393',
#   '17503',
#   '17509',
#   '17722',
#   '18035',
#   '18408',
#   '18409',
#   '18482',
#   '18614',
#   '18954',
#   '18973',
#   '19165',
#   '19721',
#   '19821',
#   '19877',
#   '19931',
#   '20018',
#   '20042',
#   '20250',
#   '20366',
#   '20594',
#   '20637',
#   '20645',
#   '20649',
#   '20723',
#   '20763',
#   '20873',
#   '21091',
#   '21243',
#   '21493'],
#  'barley': ['5',
#   '395',
#   '501',
#   '1067',
#   '1652',
#   '1970',
#   '2044',
#   '2171',
#   '2172',
#   '2191',
#   '2217',
#   '2232',
#   '2364',
#   '3132',
#   '3324',
#   '4280',
#   '4296',
#   '4444',
#   '5184',
#   '5467',
#   '5610',
#   '5640',
#   '6626',
#   '7205',
#   '7579',
#   '8213',
#   '8257',
#   '8759',
#   '9786',
#   '9865',
#   '9958',
#   '10175',
#   '11208',
#   '11316',
#   '11885',
#   '12428',
#   '13099',
#   '13744',
#   '13795',
#   '13852',
#   '13856',
#   '14230',
#   '15618',
#   '15649',
#   '15676',
#   '15728',
#   '15871',
#   '15875',
#   '15952',
#   '17010',
#   '17351',
#   '17380',
#   '17767',
#   '17769',
#   '18024',
#   '18263',
#   '18529',
#   '18908',
#   '19275',
#   '19668'],
#  'oat': ['5',
#   '97',
#   '197',
#   '417',
#   '822',
#   '855',
#   '1405',
#   '1868',
#   '8759',
#   '12381',
#   '13852',
#   '14068',
#   '15871',
#   '15875',
#   '15952',
#   '16071',
#   '19275',
#   '19668'],
#  'sorghum': ['5',
#   '6',
#   '97',
#   '1131',
#   '1369',
#   '1582',
#   '1843',
#   '3981',
#   '5467',
#   '5610',
#   '5636',
#   '6890',
#   '8140',
#   '8446',
#   '8759',
#   '9521',
#   '10175',
#   '11091',
#   '11178',
#   '11609',
#   '12052',
#   '12160',
#   '12417',
#   '13852',
#   '13856',
#   '15043',
#   '15500',
#   '15567',
#   '15871',
#   '15875',
#   '15917',
#   '15952',
#   '16071',
#   '16753',
#   '17092',
#   '18482'],
#  'veg-oil': ['6',
#   '69',
#   '200',
#   '235',
#   '263',
#   '274',
#   '308',
#   '313',
#   '320',
#   '332',
#   '833',
#   '885',
#   '944',
#   '1054',
#   '1110',
#   '1211',
#   '1439',
#   '1848',
#   '2117',
#   '2420',
#   '2456',
#   '2975',
#   '3408',
#   '3499',
#   '3502',
#   '3537',
#   '3540',
#   '3670',
#   '3950',
#   '4035',
#   '4138',
#   '4199',
#   '4305',
#   '4436',
#   '4650',
#   '4681',
#   '5142',
#   '5152',
#   '5169',
#   '5208',
#   '5218',
#   '5285',
#   '5292',
#   '5315',
#   '5391',
#   '5432',
#   '5506',
#   '5635',
#   '5655',
#   '5761',
#   '5791',
#   '5891',
#   '6058',
#   '6062',
#   '6342',
#   '6344',
#   '6354',
#   '6412',
#   '6421',
#   '6535',
#   '6585',
#   '6954',
#   '6993',
#   '6994',
#   '7037',
#   '7515',
#   '7625',
#   '8003',
#   '8084',
#   '8086',
#   '8139',
#   '8156',
#   '8159',
#   '8307',
#   '8444',
#   '8596',
#   '9193',
#   '9211',
#   '9500',
#   '9550',
#   '9673',
# ...
#   '11778',
#   '12585',
#   '12746',
#   '13080',
#   '13179',
#   '13422',
#   '13501',
#   '13738',
#   '14833',
#   '14840',
#   '14892',
#   '16193',
#   '16362',
#   '16945',
#   '16956',
#   '17105',
#   '17477',
#   '18781',
#   '19088',
#   '19367',
#   '20782',
#   '20911'],
#  'palmkernel': ['235', '11778', '20911'],
#  'tea': ['235',
#   '275',
#   '7396',
#   '7545',
#   '9153',
#   '9327',
#   '10268',
#   '10406',
#   '12754',
#   '12907',
#   '16225',
#   '17060',
#   '17392',
#   '17494',
#   '19672',
#   '19982'],
#  'plywood': ['235', '3942', '12943', '12948'],
#  'ipi': ['252',
#   '432',
#   '450',
#   '491',
#   '495',
#   '1079',
#   '1158',
#   '1697',
#   '2143',
#   '2158',
#   '2618',
#   '2776',
#   '2990',
#   '2995',
#   '3328',
#   '3432',
#   '3436',
#   '3457',
#   '3818',
#   '4005',
#   '4060',
#   '4770',
#   '4771',
#   '4944',
#   '4993',
#   '5052',
#   '5178',
#   '5196',
#   '5211',
#   '5240',
#   '5825',
#   '5845',
#   '5848',
#   '6158',
#   '6375',
#   '6526',
#   '7251',
#   '7403',
#   '7606',
#   '7623',
#   '7744',
#   '7960',
#   '8063',
#   '8171',
#   '8180',
#   '8185',
#   '8190',
#   '8363',
#   '8511',
#   '8585',
#   '8661',
#   '8671',
#   '9695',
#   '9776',
#   '10230',
#   '10283',
#   '10285',
#   '10314',
#   '10379',
#   '10520',
#   '10591',
#   '11280',
#   '11379',
#   '11562',
#   '11803',
#   '11804',
#   '11881',
#   '12062',
#   '12241',
#   '12403',
#   '12407',
#   '12451',
#   '12466',
#   '12482',
#   '12552',
#   '12771',
#   '12838',
#   '13238',
#   '13559',
#   '14106',
#   '14652',
#   '14854',
#   '15195',
#   '16032',
#   '16142',
#   '16208',
#   '16843',
#   '16853',
#   '16897',
#   '16952',
#   '16959',
#   '16960',
#   '16967',
#   '17094',
#   '17106',
#   '17129',
#   '17170',
#   '17188',
#   '17229',
#   '17303',
#   '17379',
#   '17897',
#   '17912',
#   '17941',
#   '17997',
#   '17998',
#   '18454',
#   '18510',
#   '18535',
#   '18536',
#   '19046',
#   '19077',
#   '19604',
#   '19715',
#   '19722',
#   '19728',
#   '19741',
#   '19974',
#   '21207',
#   '21368',
#   '21423',
#   '21575',
#   '21578'],
#  'yen': ['257',
#   '292',
#   '872',
#   '909',
#   '1770',
#   '1926',
#   '2178',
#   '2190',
#   '2286',
#   '2354',
#   '3419',
#   '3421',
#   '3532',
#   '4109',
#   '4633',
#   '4675',
#   '4680',
#   '4703',
#   '4709',
#   '5200',
#   '5204',
#   '5206',
#   '5271',
#   '5978',
#   '6338',
#   '6357',
#   '8079',
#   '9149',
#   '9213',
#   '9222',
#   '9698',
#   '9701',
#   '9762',
#   '9946',
#   '10131',
#   '10364',
#   '10679',
#   '10681',
#   '10684',
#   '10689',
#   '10696',
#   '10718',
#   '10762',
#   '10766',
#   '10769',
#   '10770',
#   '10804',
#   '11167',
#   '11203',
#   '11254',
#   '11675',
#   '11764',
#   '11772',
#   '11868',
#   '12145',
#   '12470',
#   '12895',
#   '13544',
#   '14654',
#   '14710',
#   '14767',
#   '14913',
#   '15400',
#   '15432',
#   '15454',
#   '15455',
#   '15470',
#   '15483',
#   '15503',
#   '15549',
#   '16976',
#   '16977',
#   '17064',
#   '17065',
#   '17068',
#   '17069',
#   '17078',
#   '17088',
#   '17138',
#   '17209',
#   '17297',
#   '17522',
#   '17533',
#   '18259',
#   '18363',
#   '18370',
#   '18862',
#   '19061',
#   '20501',
#   '20862',
#   '21542',
#   '21573'],
#  'alum': ['272',
#   '377',
#   '921',
#   '938',
#   '1263',
#   '1300',
#   '1332',
#   '1832',
#   '3957',
#   '4697',
#   '5149',
#   '5243',
#   '5868',
#   '6189',
#   '6195',
#   '6546',
#   '7263',
#   '7574',
#   '7577',
#   '7602',
#   '7779',
#   '7868',
#   '7905',
#   '8873',
#   '9226',
#   '9326',
#   '9738',
#   '9892',
#   '10258',
#   '10322',
#   '10324',
#   '10593',
#   '10709',
#   '10875',
#   '11124',
#   '11273',
#   '11371',
#   '11767',
#   '12256',
#   '12484',
#   '12836',
#   '12884',
#   '13507',
#   '13608',
#   '13980',
#   '14649',
#   '15099',
#   '15361',
#   '15368',
#   '16179',
#   '16318',
#   '16320',
#   '16750',
#   '16868',
#   '16944',
#   '17228',
#   '17287',
#   '17312',
#   '17388',
#   '17698',
#   '17702',
#   '17714',
#   '17870',
#   '17874',
#   '18093',
#   '18356',
#   '18505',
#   '18920',
#   '18930',
#   '19037',
#   '19041',
#   '19329',
#   '19367',
#   '19476',
#   '19540',
#   '20003',
#   '20055',
#   '20058',
#   '20060',
#   '20076',
#   '21526'],
#  'income': ['287',
#   '2618',
#   '3173',
#   '3346',
#   '3432',
#   '3606',
#   '5161',
#   '7005',
#   '7006',
#   '7015',
#   '7036',
#   '7098',
#   '7099',
#   '8043',
#   '9005',
#   '9574',
#   '10144',
#   '10602',
#   '10604',
#   '11796',
#   '12498',
#   '13216',
#   '13476',
#   '13726',
#   '14332',
#   '16118',
#   '16501',
#   '17091',
#   '17379',
#   '17525',
#   '17828',
#   '17831',
#   '17832',
#   '17838',
#   '17996',
#   '18008',
#   '18534',
#   '18540',
#   '18546',
#   '18550',
#   '18664',
#   '18665',
#   '18672',
#   '18911',
#   '19003'],
#  'gold': ['309',
#   '314',
#   '329',
#   '448',
#   '462',
#   '488',
#   '549',
#   '613',
#   '626',
#   '630',
#   '669',
#   '697',
#   '935',
#   '1005',
#   '1072',
#   '1082',
#   '1607',
#   '1897',
#   '1918',
#   '1942',
#   '2073',
#   '2411',
#   '2559',
#   '2753',
#   '2762',
#   '2782',
#   '2785',
#   '2880',
#   '2983',
#   '3322',
#   '3327',
#   '3574',
#   '3625',
#   '3646',
#   '3704',
#   '3793',
#   '3953',
#   '3997',
#   '4058',
#   '4066',
#   '4407',
#   '4648',
#   '4708',
#   '4816',
#   '4902',
#   '4926',
#   '4942',
#   '5209',
#   '5255',
#   '5310',
#   '5323',
#   '5481',
#   '5526',
#   '5541',
#   '5558',
#   '5564',
#   '5567',
#   '5813',
#   '5890',
#   '5932',
#   '5948',
#   '5958',
#   '6207',
#   '6218',
#   '6245',
#   '6658',
#   '6872',
#   '6957',
#   '6985',
#   '7023',
#   '7088',
#   '7166',
#   '7237',
#   '7629',
#   '7645',
#   '7775',
#   '7781',
#   '7823',
#   '7985',
#   '8068',
#   '8331',
#   '8462',
#   '8477',
#   '8757',
#   '8854',
#   '8857',
#   '8871',
#   '8877',
#   '8948',
#   '9104',
#   '9190',
#   '9281',
#   '9319',
#   '9453',
#   '9489',
#   '9799',
#   '9853',
#   '9866',
#   '9890',
#   '10214',
#   '10216',
#   '10396',
#   '10485',
#   '10546',
#   '10662',
#   '10811',
#   '10861',
#   '10868',
#   '10969',
#   '10994',
#   '11014',
#   '11038',
#   '11627',
#   '11638',
#   '11830',
#   '11839',
#   '11852',
#   '12442',
#   '12519',
#   '12796',
#   '12867',
#   '12963',
#   '12987',
#   '13116',
#   '13526',
#   '13641',
#   '13668',
#   '13675',
#   '13690',
#   '13757',
#   '13791',
#   '14038',
#   '14208',
#   '14250',
#   '14280',
#   '14455',
#   '14554',
#   '14572',
#   '14842',
#   '14845',
#   '14896',
#   '14908',
#   '15411',
#   '15471',
#   '15481',
#   '15518',
#   '15803',
#   '15811',
#   '16009',
#   '16149',
#   '16162',
#   '16212',
#   '16248',
#   '16286',
#   '16589',
#   '16596',
#   '16604',
#   '16781',
#   '16971',
#   '17011',
#   '17116',
#   '17122',
#   '17163',
#   '17224',
#   '17264',
#   '17273',
#   '17285',
#   '17457',
#   '17526',
#   '17541',
#   '17622',
#   '17632',
#   '17654',
#   '17714',
#   '18007',
#   '18013',
#   '18132',
#   '18147',
#   '18176',
#   '18194',
#   '18387',
#   '18388',
#   '18415',
#   '19152',
#   '19764',
#   '19802',
#   '19808',
#   '20096',
#   '20099',
#   '20699',
#   '20867',
#   '20987',
#   '21293',
#   '21314',
#   '21576'],
#  'platinum': ['309',
#   '448',
#   '2782',
#   '2880',
#   '9345',
#   '15420',
#   '16162',
#   '16248',
#   '18013',
#   '18489',
#   '18888',
#   '19295'],
#  'strategic-metal': ['309',
#   '346',
#   '1864',
#   '2186',
#   '2936',
#   '2942',
#   '3010',
#   '3460',
#   '3497',
#   '4252',
#   '5693',
#   '7775',
#   '10151',
#   '11999',
#   '12007',
#   '12727',
#   '13052',
#   '13251',
#   '13285',
#   '13287',
#   '14719',
#   '15160',
#   '15420',
#   '15838',
#   '15872',
#   '16894',
#   '17337',
#   '17480',
#   '17486',
#   '17783',
#   '17805',
#   '18348',
#   '18390',
#   '18466',
#   '18872',
#   '18944',
#   '20199'],
#  'tapioca': ['310', '327', '2974', '17380'],
#  'tin': ['311',
#   '656',
#   '688',
#   '908',
#   '1929',
#   '3484',
#   '4122',
#   '6934',
#   '7533',
#   '7592',
#   '7877',
#   '8055',
#   '8415',
#   '8416',
#   '8427',
#   '8933',
#   '10332',
#   '11224',
#   '11801',
#   '12909',
#   '13185',
#   '13275',
#   '14302',
#   '14832',
#   '14844',
#   '14877',
#   '15089',
#   '15112',
#   '15219',
#   '15624',
#   '15817',
#   '16491',
#   '16504',
#   '16859',
#   '16988',
#   '17311',
#   '17731',
#   '18924',
#   '19065',
#   '19367',
#   '19516',
#   '20458'],
#  'rapeseed': ['313',
#   '327',
#   '1151',
#   '2172',
#   '3206',
#   '4040',
#   '4083',
#   '4512',
#   '7151',
#   '8213',
#   '10758',
#   '11052',
#   '11172',
#   '11275',
#   '11885',
#   '12076',
#   '12254',
#   '12478',
#   '12710',
#   '12712',
#   '12982',
#   '13179',
#   '13313',
#   '14603',
#   '14716',
#   '15129',
#   '15721',
#   '16433',
#   '16789',
#   '17010',
#   '17021',
#   '17132',
#   '18345',
#   '18382',
#   '18391',
#   '18431',
#   '18482',
#   '19277',
#   '19549',
#   '19668',
#   '20208'],
#  'groundnut-oil': ['313', '15500'],
#  'rape-oil': ['320',
#   '3950',
#   '8159',
#   '10330',
#   '10758',
#   '13653',
#   '14183',
#   '14189',
#   '15500',
#   '16080',
#   '18781'],
#  'cornglutenfeed': ['327', '2913'],
#  'citruspulp': ['327'],
#  'rape-meal': ['327'],
#  'wool': ['425', '12502'],
#  'inventories': ['430',
#   '434',
#   '1459',
#   '4808',
#   '4811',
#   '5196',
#   '8114',
#   '8746',
#   '17229',
#   '17303'],
#  'l-cattle': ['443',
#   '2389',
#   '3278',
#   '4564',
#   '5896',
#   '6492',
#   '15290',
#   '17176',
#   '20620'],
#  'silver': ['488',
#   '1942',
#   '3574',
#   '3646',
#   '3862',
#   '3868',
#   '4926',
#   '4942',
#   '6515',
#   '6557',
#   '7645',
#   '7775',
#   '8854',
#   '8877',
#   '9195',
#   '9890',
#   '10485',
#   '11839',
#   '11852',
#   '12243',
#   '12484',
#   '12639',
#   '12796',
#   '13119',
#   '13526',
#   '14038',
#   '14250',
#   '14554',
#   '14572',
#   '16009',
#   '16248',
#   '16971',
#   '17142',
#   '17149',
#   '17154',
#   '17177',
#   '17187',
#   '17423',
#   '17654',
#   '17714',
#   '18013',
#   '18132',
#   '18489',
#   '19764',
#   '21314'],
#  'heat': ['652',
#   '829',
#   '834',
#   '2696',
#   '2900',
#   '3181',
#   '3310',
#   '4007',
#   '5061',
#   '5706',
#   '7397',
#   '10567',
#   '11491',
#   '11880',
#   '12608',
#   '12670',
#   '12935',
#   '13749',
#   '13847',
#   '14000',
#   '14107',
#   '14558',
#   '14698',
#   '15038',
#   '15520',
#   '15607',
#   '15829',
#   '16991',
#   '17102',
#   '17409',
#   '18405',
#   '19223'],
#  'fuel': ['652',
#   '1660',
#   '1856',
#   '2957',
#   '3995',
#   '4672',
#   '4710',
#   '4891',
#   '5427',
#   '5630',
#   '5683',
#   '6087',
#   '6798',
#   '7397',
#   '8033',
#   '8041',
#   '9672',
#   '10486',
#   '10860',
#   '11070',
#   '12315',
#   '14000',
#   '14732',
#   '14953',
#   '15924',
#   '16314',
#   '17101',
#   '17161',
#   '17242',
#   '17376',
#   '17409',
#   '17427',
#   '17441',
#   '17473',
#   '17634',
#   '18228',
#   '18444',
#   '18468',
#   '18480',
#   '18858',
#   '18902',
#   '19015',
#   '19200',
#   '19220',
#   '19497',
#   '19530',
#   '20406'],
#  'hog': ['798',
#   '1970',
#   '2226',
#   '2572',
#   '3057',
#   '3278',
#   '3318',
#   '3595',
#   '4206',
#   '4833',
#   '5333',
#   '5928',
#   '7101',
#   '7660',
#   '8241',
#   '9060',
#   '9579',
#   '9585',
#   '10415',
#   '10857',
#   '11914',
#   '13768',
#   '14161',
#   '14163',
#   '15532',
#   '15611',
#   '16255',
#   '16980',
#   '17090',
#   '17319',
#   '17390',
#   '17512',
#   '17823',
#   '17827',
#   '17990',
#   '18373',
#   '18653',
#   '19145',
#   '19555',
#   '19607',
#   '20196',
#   '21367',
#   '21433'],
#  'propane': ['829', '10567', '13130', '17927', '19397', '21486'],
#  'gas': ['829',
#   '1230',
#   '1362',
#   '1520',
#   '1660',
#   '1786',
#   '1793',
#   '1851',
#   '1856',
#   '1857',
#   '1878',
#   '2011',
#   '2140',
#   '2156',
#   '2493',
#   '2507',
#   '2828',
#   '2900',
#   '3551',
#   '3855',
#   '3929',
#   '3995',
#   '4491',
#   '4507',
#   '4670',
#   '4705',
#   '4940',
#   '5037',
#   '5061',
#   '5145',
#   '6087',
#   '6836',
#   '6871',
#   '6893',
#   '7150',
#   '7152',
#   '7651',
#   '7671',
#   '7854',
#   '7952',
#   '7972',
#   '8072',
#   '8882',
#   '8964',
#   '9039',
#   '9602',
#   '9614',
#   '9634',
#   '9912',
#   '9915',
#   '9944',
#   '10003',
#   '10038',
#   '11406',
#   '11491',
#   '11699',
#   '11880',
#   '11950',
#   '12209',
#   '12691',
#   '13234',
#   '14698',
#   '14704',
#   '14732',
#   '14863',
#   '15123',
#   '15339',
#   '15344',
#   '15351',
#   '16581',
#   '17043',
#   '17101',
#   '17125',
#   '17135',
#   '17161',
#   '17173',
#   '17242',
#   '17409',
#   '17427',
#   '17441',
#   '17446',
#   '17463',
#   '17472',
#   '17878',
#   '18146',
#   '18311',
#   '18367',
#   '18405',
#   '18480',
#   '19014',
#   '19018',
#   '19034',
#   '19083',
#   '19664',
#   '20621',
#   '20730'],
#  'orange': ['832',
#   '1114',
#   '1121',
#   '1139',
#   '1350',
#   '1361',
#   '1761',
#   '2390',
#   '3098',
#   '3109',
#   '3149',
#   '3315',
#   '3892',
#   '4133',
#   '4541',
#   '6118',
#   '7357',
#   '7920',
#   '8883',
#   '9327',
#   '10021',
#   '11071',
#   '12023',
#   '12265',
#   '12359',
#   '12360',
#   '12737',
#   '12892',
#   '14453',
#   '14474',
#   '14477',
#   '15675',
#   '15846',
#   '15847',
#   '15854',
#   '15855',
#   '15929',
#   '15960',
#   '16627',
#   '16630',
#   '16784',
#   '16947',
#   '17358',
#   '17443',
#   '19074',
#   '19567'],
#  'saudriyal': ['915', '9170', '9753', '13533', '14811'],
#  'zinc': ['1077',
#   '2186',
#   '3104',
#   '3163',
#   '3183',
#   '3207',
#   '3454',
#   '3862',
#   '5153',
#   '6144',
#   '6451',
#   '6995',
#   '7775',
#   '7842',
#   '8233',
#   '8308',
#   '8854',
#   '8877',
#   '10485',
#   '11190',
#   '12484',
#   '13877',
#   '14572',
#   '14882',
#   '16194',
#   '16958',
#   '17109',
#   '17238',
#   '17312',
#   '17480',
#   '17486',
#   '17783',
#   '17805',
#   '18337',
#   '18385',
#   '18411',
#   '18412',
#   '18414',
#   '18416',
#   '18457',
#   '18462',
#   '18943',
#   '18945',
#   '19431',
#   '19477',
#   '19692',
#   '19764',
#   '21004'],
#  'pet-chem': ['1493',
#   '1509',
#   '2371',
#   '2745',
#   '3120',
#   '3780',
#   '4054',
#   '4299',
#   '5150',
#   '5421',
#   '5484',
#   '6561',
#   '7122',
#   '7452',
#   '8088',
#   '8957',
#   '8971',
#   '9032',
#   '9077',
#   '9204',
#   '10006',
#   '10030',
#   '10581',
#   '10886',
#   '11624',
#   '11625',
#   '12404',
#   '12439',
#   '12599',
#   '12770',
#   '12989',
#   '12999',
#   '14689',
#   '15063',
#   '15187',
#   '15716',
#   '16596',
#   '17079',
#   '17135',
#   '17228',
#   '17287',
#   '17312',
#   '17563',
#   '17580',
#   '17585',
#   '17743',
#   '18191',
#   '18217',
#   '18381',
#   '18386',
#   '18398',
#   '18807',
#   '18852',
#   '18966',
#   '19397',
#   '19903',
#   '20549',
#   '20710'],
#  'lumber': ['1730',
#   '2793',
#   '3568',
#   '3942',
#   '4294',
#   '4594',
#   '4793',
#   '4923',
#   '5115',
#   '5132',
#   '7223',
#   '7318',
#   '7566',
#   '8422',
#   '9692',
#   '10055',
#   '11519',
#   '12405',
#   '12943',
#   '12948',
#   '13213',
#   '13217',
#   '14840',
#   '15419',
#   '16092',
#   '16748',
#   '17166',
#   '17371',
#   '17670',
#   '17686',
#   '17768',
#   '18281',
#   '18797',
#   '18885',
#   '18914',
#   '19246',
#   '19371',
#   '19496',
#   '19641',
#   '19845',
#   '20790'],
#  'potato': ['1970', '3317', '8713', '15620', '15858', '15859'],
#  'ringgit': ['1999', '8111'],
#  'lead': ['2186',
#   '3211',
#   '3454',
#   '5153',
#   '6144',
#   '6451',
#   '7396',
#   '7775',
#   '7809',
#   '7842',
#   '8854',
#   '8877',
#   '10485',
#   '11935',
#   '11958',
#   '12484',
#   '14572',
#   '14863',
#   '15516',
#   '15556',
#   '15563',
#   '15767',
#   '16289',
#   '17109',
#   '17480',
#   '17486',
#   '17783',
#   '17805',
#   '18337',
#   '18411',
#   '18412',
#   '18414',
#   '18416',
#   '18457',
#   '18571',
#   '19431',
#   '19477',
#   '19764',
#   '21004'],
#  'groundnut': ['2359',
#   '2420',
#   '6756',
#   '12254',
#   '12275',
#   '12372',
#   '13323',
#   '13637',
#   '14819',
#   '14951',
#   '15574',
#   '16147',
#   '16972',
#   '19101'],
#  'can': ['2406', '2824', '3535', '14767', '17418'],
#  'fishmeal': ['2557', '3135', '13491'],
#  'palladium': ['2782', '2880', '15420'],
#  'nickel': ['2782',
#   '2880',
#   '4769',
#   '5693',
#   '7126',
#   '10678',
#   '12484',
#   '14297',
#   '14928',
#   '16998',
#   '17118'],
#  'instal-debt': ['3016',
#   '3341',
#   '3353',
#   '5035',
#   '9703',
#   '12838',
#   '13288',
#   '13489',
#   '14566',
#   '14612',
#   '15828',
#   '18296'],
#  'dfl': ['3024', '10344', '17620'],
#  'dmk': ['3076',
#   '3698',
#   '3732',
#   '5823',
#   '10718',
#   '10751',
#   '11212',
#   '11944',
#   '11972',
#   '12522',
#   '12525',
#   '12877',
#   '13919',
#   '17396',
#   '17620',
#   '18136',
#   '21496',
#   '21542'],
#  'stg': ['3283',
#   '3535',
#   '3666',
#   '6360',
#   '6394',
#   '7429',
#   '8884',
#   '9848',
#   '11000',
#   '11972',
#   '12096',
#   '12121',
#   '12406',
#   '12418',
#   '12447',
#   '12588',
#   '12593',
#   '12601',
#   '12607',
#   '12642',
#   '12673',
#   '14767',
#   '17367',
#   '18156'],
#  'coconut-oil': ['3540', '6421', '8596', '13080', '17477', '18781', '20911'],
#  'austdlr': ['3698',
#   '3732',
#   '5779',
#   '5811',
#   '5823',
#   '10931',
#   '12525',
#   '15381'],
#  'corn-oil': ['3950'],
#  'cpu': ['5242',
#   '5388',
#   '5460',
#   '5485',
#   '12738',
#   '14143',
#   '19139',
#   '19502',
#   '21245'],
#  'peseta': ['5412'],
#  'naphtha': ['5801',
#   '6535',
#   '7397',
#   '17101',
#   '17880',
#   '18480',
#   '19497',
#   '19903'],
#  'nzdlr': ['6143', '6945', '10931', '16168', '18625', '21561'],
#  'cotton-oil': ['6412', '15871', '18781'],
#  'coconut': ['7026',
#   '8112',
#   '10712',
#   '10720',
#   '11836',
#   '17477',
#   '20026',
#   '20045'],
#  'rand': ['7043', '8901', '8990', '9310', '9336', '21535'],
#  'pork-belly': ['7921', '7924', '8008', '17176'],
#  'f-cattle': ['9646', '13697', '14307', '16236', '17165', '17176'],
#  'castorseed': ['10300'],
#  'castor-oil': ['10300', '19672'],
#  'lit': ['10636', '17293', '17300'],
#  'rupiah': ['10718'],
#  'skr': ['11972'],
#  'nkr': ['11972', '19537', '19541'],
#  'dkr': ['11972'],
#  'sun-meal': ['12361', '13861', '15500'],
#  'lin-meal': ['12361'],
#  'cruzado': ['14655'],
#  'cottonseed': ['16147'],
#  'bfr': ['16951'],
#  'hk': ['17370'],
#  'sfr': ['17395', '17397', '18136']}

# %%
import pickle
path = '../corpus/topics.dict'
with open(path, 'wb') as f:
    pickle.dump(topics_dict, f)

# %%
# with open(path, 'rb') as f:
#     dct = pickle.load(f)
# Out:
# {'1': ['cocoa'],
#  '2': ['acq'],
#  '3': ['money-supply', 'acq'],
#  '4': ['acq', 'earn'],
#  '5': ['grain', 'wheat', 'corn', 'barley', 'oat', 'sorghum'],
#  '6': ['veg-oil',
#   'linseed',
#   'lin-oil',
#   'soy-oil',
#   'sun-oil',
#   'soybean',
#   'oilseed',
#   'corn',
#   'sunseed',
#   'grain',
#   'sorghum',
#   'wheat'],
#  '7': ['acq'],
#  '8': ['reserves', 'money-supply'],
#  '9': ['earn'],
#  '10': ['acq'],
#  '11': ['earn'],
#  '12': ['earn', 'acq'],
#  '13': ['earn'],
#  '14': ['earn'],
#  '15': ['acq'],
#  '16': ['acq', 'earn'],
#  '17': ['acq'],
#  '18': ['earn'],
#  '19': ['wheat', 'grain'],
#  '20': ['money-supply', 'interest'],
#  '21': ['acq'],
#  '22': ['copper'],
#  '23': ['earn'],
#  '24': ['earn'],
#  '25': ['acq'],
#  '26': ['interest'],
#  '27': ['earn'],
#  '28': ['crude'],
#  '29': ['housing'],
#  '30': ['money-supply'],
#  '31': ['money-supply'],
#  '32': ['wheat', 'grain'],
#  '33': ['acq'],
#  '34': ['acq'],
#  '35': ['earn'],
#  '36': ['earn'],
#  '37': ['earn'],
#  '38': ['earn'],
#  '39': ['acq'],
#  '40': ['earn'],
#  '41': ['earn'],
#  '42': ['coffee'],
#  '43': ['grain', 'earn'],
#  '44': ['acq', 'ship'],
#  '45': ['acq'],
#  '46': ['sugar'],
#  '47': ['trade'],
#  '48': ['reserves'],
#  '49': ['ship'],
#  '50': ['earn'],
#  '51': ['grain', 'corn'],
#  '52': ['money-supply'],
#  '53': ['earn'],
#  '54': ['retail', 'lei'],
#  '55': ['wheat', 'grain'],
#  '56': ['earn'],
#  '57': ['grain', 'corn'],
#  '58': ['money-supply'],
#  '59': ['ship'],
#  '60': ['money-supply'],
#  '61': ['crude', 'trade'],
#  '62': ['money-supply'],
#  '63': ['money-supply'],
#  '64': ['earn'],
#  '65': ['earn'],
#  '66': ['earn'],
#  '67': ['money-supply'],
#  '68': ['acq'],
#  '69': ['veg-oil', 'soybean', 'oilseed', 'meal-feed', 'soy-meal'],
#  '70': ['acq', 'earn'],
#  '71': ['earn'],
#  '72': ['jet', 'earn'],
#  '73': ['acq', 'earn'],
#  '74': ['earn'],
#  '75': ['coffee'],
#  '76': ['money-supply'],
#  '77': ['money-supply'],
#  '78': ['money-supply'],
#  '79': ['acq', 'earn'],
#  '80': ['money-supply'],
#  '81': ['money-supply'],
#  '82': ['earn'],
#  '83': ['earn'],
#  '84': ['earn'],
#  '85': ['earn'],
#  '86': ['earn'],
#  '87': ['earn'],
#  '88': ['acq'],
#  '89': ['earn'],
#  '90': ['acq'],
#  '91': ['nat-gas', 'earn'],
#  '92': ['money-supply'],
#  '93': ['earn'],
#  '94': ['money-supply'],
#  '95': ['money-supply'],
#  '96': ['acq'],
#  '97': ['grain',
#   'wheat',
#   'corn',
#   'oat',
#   'rye',
#   'sorghum',
#   'soybean',
#   'oilseed'],
#  '98': ['earn'],
#  '99': ['money-supply'],
#  '100': ['money-supply'],
#  '101': ['money-supply'],
#  '102': ['money-supply'],
#  '103': ['money-supply'],
#  '104': ['cotton'],
#  '105': ['sugar'],
#  '106': ['grain', 'ship'],
#  '107': ['crude', 'ship'],
#  '108': ['earn'],
#  '109': ['money-supply'],
#  '110': ['acq'],
#  '111': ['money-supply'],
#  '112': ['money-fx', 'acq'],
#  '113': ['earn'],
#  '114': ['acq'],
#  '115': ['interest', 'earn'],
#  '116': ['acq'],
#  '117': ['acq', 'earn'],
#  '118': ['money-supply', 'acq'],
#  '119': ['acq'],
#  '120': ['acq', 'earn'],
#  '121': ['carcass', 'livestock'],
#  '122': ['trade', 'acq'],
#  '123': ['earn'],
#  '124': ['grain'],
#  '125': ['acq'],
#  '126': ['earn'],
#  '127': ['crude'],
#  '128': ['acq'],
#  '129': ['earn'],
#  '130': ['earn'],
#  '131': ['acq'],
#  '132': ['money-supply'],
#  '133': ['money-supply'],
#  '134': ['acq'],
#  '135': ['acq'],
#  '136': ['grain'],
#  '137': ['interest'],
#  '138': ['earn'],
#  '139': ['earn'],
#  '140': ['earn'],
#  '141': ['interest'],
#  '142': ['earn'],
#  '143': ['earn'],
#  '144': ['crude'],
#  '145': ['earn'],
#  '146': ['earn'],
#  '147': ['earn'],
#  '148': ['acq'],
#  '149': ['acq'],
#  '150': ['acq'],
#  '151': ['earn'],
#  '152': ['earn'],
#  '153': ['acq'],
#  '154': ['acq'],
#  '155': ['money-supply'],
#  '156': ['acq'],
#  '157': ['acq'],
#  '158': ['money-supply'],
#  '159': ['money-supply'],
#  '160': ['earn'],
#  '161': ['interest'],
#  '162': ['acq'],
#  '163': ['earn'],
#  '164': ['earn'],
#  '165': ['earn'],
#  '166': ['earn'],
#  '167': ['earn'],
#  '168': ['earn'],
#  '169': ['earn'],
#  '170': ['acq'],
#  '171': ['money-supply'],
#  '172': ['acq'],
#  '173': ['money-supply'],
#  '174': ['housing'],
#  '175': ['interest'],
#  '176': ['nat-gas'],
#  '177': ['livestock', 'acq'],
#  '178': ['gnp', 'crude'],
#  '179': ['cpi', 'gnp'],
#  '180': ['grain', 'wheat'],
#  '181': ['gnp', 'rubber'],
#  '182': ['cpi'],
#  '183': ['earn'],
#  '184': ['acq'],
#  '185': ['acq'],
#  '186': ['acq'],
#  '187': ['earn'],
#  '188': ['cpi'],
#  '189': ['crude'],
#  '190': ['interest'],
#  '191': ['crude'],
#  '192': ['iron-steel', 'earn'],
#  '193': ['grain', 'corn'],
#  '194': ['crude'],
#  '195': ['acq'],
#  '196': ['earn'],
#  '197': ['grain', 'corn', 'oat'],
#  '198': ['money-supply'],
#  '199': ['acq'],
#  '200': ['veg-oil', 'oilseed', 'meal-feed', 'soybean', 'soy-oil', 'soy-meal'],
#  '201': ['earn'],
#  '202': ['earn'],
#  '203': ['money-supply'],
#  '204': ['money-supply', 'interest'],
#  '205': ['trade', 'acq'],
#  '206': ['acq'],
#  '207': ['money-supply', 'acq'],
#  '208': ['trade'],
#  '209': ['cpi', 'gnp'],
#  '210': ['earn'],
#  '211': ['crude'],
#  '212': ['earn'],
#  '213': ['cpi'],
#  '214': ['earn'],
#  '215': ['acq'],
#  '216': ['money-supply'],
#  '217': ['wpi', 'jobs'],
#  '218': ['money-fx', 'trade'],
#  '219': ['acq', 'interest'],
#  '220': ['money-supply'],
#  '221': ['money-fx', 'interest'],
#  '222': ['money-supply'],
#  '223': ['money-fx'],
#  '224': ['money-fx', 'dlr'],
#  '225': ['interest'],
#  '226': ['money-fx', 'acq'],
#  '227': ['gnp', 'bop'],
#  '228': ['grain', 'rice'],
#  '229': ['soybean', 'red-bean', 'oilseed'],
#  '230': ['acq', 'interest'],
#  '231': ['interest'],
#  '232': ['coffee'],
#  '233': ['interest'],
#  '234': ['interest'],
#  '235': ['grain',
#   'wheat',
#   'rice',
#   'veg-oil',
#   'soybean',
#   'sugar',
#   'rubber',
#   'copra-cake',
#   'corn',
#   'palm-oil',
#   'palmkernel',
#   'coffee',
#   'tea',
#   'plywood',
#   'soy-meal',
#   'cotton'],
#  '236': ['crude'],
#  '237': ['crude'],
#  '238': ['gnp', 'trade'],
#  '239': ['money-supply', 'ship'],
#  '240': ['acq', 'interest'],
#  '241': ['grain', 'wheat'],
#  '242': ['crude'],
#  '243': ['crude', 'acq'],
#  '244': ['money-fx', 'dlr'],
#  '245': ['crude', 'acq'],
#  '246': ['crude'],
#  '247': ['money-fx'],
#  '248': ['crude'],
#  '249': ['coffee'],
#  '250': ['money-supply'],
#  '251': ['acq'],
#  '252': ['gnp', 'ipi'],
#  '253': ['grain', 'wheat'],
#  '254': ['grain', 'wheat'],
#  '255': ['money-supply', 'acq'],
#  '256': ['money-fx'],
#  '257': ['money-fx', 'yen'],
#  '258': ['wheat', 'grain'],
#  '259': ['sugar'],
#  '260': ['acq'],
#  '261': ['money-supply'],
#  '262': ['acq'],
#  '263': ['veg-oil', 'soy-oil'],
#  '264': ['acq'],
#  '265': ['money-supply'],
#  '266': ['acq'],
#  '267': ['meal-feed', 'copra-cake'],
#  '268': ['money-fx', 'dlr'],
#  '269': ['acq'],
#  '270': ['trade', 'interest'],
#  '271': ['trade'],
#  '272': ['alum'],
#  '273': ['crude'],
#  '274': ['veg-oil', 'palm-oil'],
#  '275': ['tea', 'cocoa', 'coffee'],
#  '276': ['money-fx', 'interest'],
#  '277': ['money-supply', 'earn'],
#  '278': ['money-fx', 'interest'],
#  '279': ['earn'],
#  '280': ['acq', 'grain'],
#  '281': ['ship'],
#  '282': ['acq', 'interest'],
#  '283': ['reserves'],
#  '284': ['reserves'],
#  '285': ['wheat', 'grain'],
#  '286': ['reserves', 'trade'],
#  '287': ['interest', 'income'],
#  '288': ['acq', 'interest'],
#  '289': ['money-supply', 'interest'],
#  '290': ['coffee'],
#  '291': ['interest'],
#  '292': ['money-fx', 'yen'],
#  '293': ['sugar'],
#  '294': ['money-supply', 'acq'],
#  '295': ['acq'],
#  '296': ['money-fx', 'interest'],
#  '297': ['oilseed', 'soybean'],
#  '298': ['acq'],
#  '299': ['earn'],
#  '300': ['money-fx', 'dlr'],
#  '301': ['acq', 'interest'],
#  '302': ['acq'],
#  '303': ['oilseed', 'soybean', 'meal-feed', 'soy-meal'],
#  '304': ['acq'],
#  '305': ['earn'],
#  '306': ['acq', 'interest'],
#  '307': ['money-fx', 'interest'],
#  '308': ['crude', 'veg-oil'],
#  '309': ['gold', 'platinum', 'strategic-metal'],
#  '310': ['meal-feed', 'tapioca'],
#  '311': ['tin'],
#  '312': ['trade', 'bop'],
#  '313': ['oilseed',
#   'sunseed',
#   'soybean',
#   'rapeseed',
#   'veg-oil',
#   'soy-oil',
#   'palm-oil',
#   'groundnut-oil'],
#  '314': ['gold'],
#  '315': ['acq'],
#  '316': ['acq'],
#  '317': ['earn'],
#  '318': ['cocoa', 'acq'],
#  '319': ['trade', 'money-supply'],
#  '320': ['veg-oil', 'rape-oil', 'palm-oil'],
#  '321': ['money-supply', 'acq'],
#  '322': ['interest'],
#  '323': ['reserves'],
#  '324': ['acq', 'coffee'],
#  '325': ['wpi', 'interest'],
#  '326': ['reserves', 'bop'],
#  '327': ['meal-feed',
#   'soy-meal',
#   'tapioca',
#   'grain',
#   'corn',
#   'cornglutenfeed',
#   'citruspulp',
#   'oilseed',
#   'rapeseed',
#   'rape-meal'],
#  '328': ['earn'],
#  '329': ['money-fx', 'gold'],
#  '330': ['money-supply'],
#  '331': ['acq'],
#  '332': ['veg-oil', 'palm-oil'],
#  '333': ['money-supply'],
#  '334': ['acq'],
#  '335': ['money-fx', 'trade'],
#  '336': ['money-fx', 'interest'],
#  '337': ['money-supply'],
#  '338': ['trade'],
#  '339': ['money-fx', 'earn'],
#  '340': ['gnp', 'jobs'],
#  '341': ['money-fx', 'interest'],
#  '342': ['trade'],
#  '343': ['sugar'],
#  '344': ['acq'],
#  '345': ['earn'],
#  '346': ['strategic-metal'],
#  '347': ['acq', 'interest'],
#  '348': ['money-fx', 'interest'],
#  '349': ['crude'],
#  '350': ['interest'],
#  '351': ['money-fx', 'interest'],
#  '352': ['crude'],
#  '353': ['crude'],
#  '354': ['trade'],
#  '355': ['earn'],
#  '356': ['earn'],
#  '357': ['cpi'],
#  '358': ['gnp', 'wpi'],
#  '359': ['gnp', 'trade'],
#  '360': ['acq'],
#  '361': ['acq'],
#  '362': ['acq'],
#  '363': ['money-supply'],
#  '364': ['trade', 'bop'],
#  '365': ['acq'],
#  '366': ['acq'],
#  '367': ['acq'],
#  '368': ['crude', 'ship'],
#  '369': ['acq'],
#  '370': ['crude'],
#  '371': ['acq'],
#  '372': ['acq'],
#  '373': ['money-supply'],
#  '374': ['cotton'],
#  '375': ['acq', 'earn'],
#  '376': ['acq'],
#  '377': ['alum'],
#  '378': ['earn'],
#  '379': ['acq'],
#  '380': ['acq'],
#  '381': ['earn'],
#  '382': ['acq'],
#  '383': ['acq'],
#  '384': ['acq'],
#  '385': ['acq'],
#  '386': ['crude', 'ship'],
#  '387': ['acq'],
#  '388': ['earn'],
#  '389': ['acq'],
#  '390': ['earn'],
#  '391': ['earn'],
#  '392': ['earn'],
#  '393': ['acq'],
#  '394': ['money-fx', 'dlr'],
#  '395': ['grain', 'wheat', 'corn', 'barley'],
#  '396': ['earn'],
#  '397': ['acq'],
#  '398': ['acq'],
#  '399': ['earn'],
#  '400': ['acq'],
#  '401': ['acq'],
#  '402': ['coffee'],
#  '403': ['money-supply'],
#  '404': ['earn'],
#  '405': ['earn'],
#  '406': ['earn'],
#  '407': ['earn'],
#  '408': ['acq'],
#  '409': ['earn'],
#  '410': ['earn'],
#  '411': ['money-fx', 'interest'],
#  '412': ['acq'],
#  '413': ['earn'],
#  '414': ['interest', 'cpi'],
#  '415': ['interest', 'cpi'],
#  '416': ['reserves'],
#  '417': ['grain', 'oat'],
#  '418': ['acq'],
#  '419': ['trade', 'interest'],
#  '420': ['earn'],
#  '421': ['interest', 'cpi'],
#  '422': ['earn'],
#  '423': ['earn'],
#  '424': ['acq'],
#  '425': ['grain', 'wheat', 'wool', 'dlr'],
#  '426': ['acq'],
#  '427': ['interest', 'cpi'],
#  '428': ['crude', 'acq'],
#  '429': ['grain', 'corn'],
#  '430': ['lei', 'inventories'],
#  '431': ['gnp', 'lei'],
#  '432': ['gnp', 'ipi'],
#  '433': ['interest'],
#  '434': ['trade', 'inventories'],
#  '435': ['earn'],
#  '436': ['acq'],
#  '437': ['acq'],
#  '438': ['earn'],
#  '439': ['earn'],
#  '440': ['acq'],
#  '441': ['acq'],
#  '442': ['acq'],
#  '443': ['livestock', 'l-cattle'],
#  '444': ['retail'],
#  '445': ['money-supply'],
#  '446': ['acq'],
#  '447': ['acq'],
#  '448': ['gold', 'acq', 'platinum'],
#  '449': ['earn'],
#  '450': ['ipi'],
#  '451': ['acq'],
#  '452': ['crude'],
#  '453': ['wpi', 'interest'],
#  '454': ['money-supply'],
#  '455': ['earn'],
#  '456': ['earn'],
#  '457': ['earn'],
#  '458': ['money-fx', 'interest'],
#  '459': ['crude'],
#  '460': ['money-fx', 'money-supply'],
#  '461': ['earn'],
#  '462': ['gold', 'interest'],
#  '463': ['acq', 'interest'],
#  '464': ['earn'],
#  '465': ['money-supply', 'interest'],
#  '466': ['earn'],
#  '467': ['acq'],
#  '468': ['earn'],
#  '469': ['acq'],
#  '470': ['earn'],
#  '471': ['crude', 'acq'],
#  '472': ['money-supply'],
#  '473': ['earn', 'acq'],
#  '474': ['acq'],
#  '475': ['money-fx', 'interest'],
#  '476': ['acq', 'grain'],
#  '477': ['acq'],
#  '478': ['acq'],
#  '479': ['acq', 'earn'],
#  '480': ['earn'],
#  '481': ['earn'],
#  '482': ['acq'],
#  '483': ['earn'],
#  '484': ['earn'],
#  '485': ['wpi', 'interest'],
#  '486': ['oilseed'],
#  '487': ['acq'],
#  '488': ['gold', 'silver'],
#  '489': ['crude'],
#  '490': ['earn'],
#  '491': ['ipi'],
#  '492': ['acq', 'interest'],
#  '493': ['acq', 'earn'],
#  '494': ['earn'],
#  '495': ['ipi'],
#  '496': ['acq'],
#  '497': ['acq'],
#  '498': ['acq'],
#  '499': ['acq'],
#  '500': ['acq', 'earn'],
#  '501': ['grain', 'corn', 'wheat', 'barley'],
#  '502': ['crude'],
#  '503': ['acq'],
#  '504': ['acq'],
#  '505': ['acq'],
#  '506': ['earn'],
#  '507': ['acq'],
#  '508': ['earn'],
#  '509': ['earn'],
#  '510': ['acq'],
#  '511': ['crude'],
#  '512': ['earn'],
#  '513': ['earn'],
#  '514': ['earn'],
#  '515': ['acq'],
#  '516': ['grain', 'corn'],
#  '517': ['earn'],
#  '518': ['ship'],
#  '519': ['money-fx', 'interest'],
#  '520': ['acq'],
#  '521': ['earn'],
#  '522': ['money-fx', 'interest'],
#  '523': ['acq', 'earn'],
#  '524': ['earn'],
#  '525': ['iron-steel'],
#  '526': ['trade'],
#  '527': ['money-supply'],
#  '528': ['earn'],
#  '529': ['earn'],
#  '530': ['earn'],
#  '531': ['earn'],
#  '532': ['acq'],
#  '533': ['earn'],
#  '534': ['earn'],
#  '535': ['earn'],
#  '536': ['earn'],
#  '537': ['earn'],
#  '538': ['earn'],
#  '539': ['earn'],
#  '540': ['money-fx', 'crude'],
#  '541': ['earn'],
#  '542': ['crude', 'nat-gas'],
#  '543': ['crude'],
#  '544': ['nat-gas'],
#  '545': ['acq'],
#  '546': ['earn'],
#  '547': ['acq'],
#  '548': ['earn'],
#  '549': ['gold', 'acq'],
#  '550': ['acq'],
#  '551': ['acq'],
#  '552': ['earn'],
#  '553': ['acq'],
#  '554': ['earn'],
#  '555': ['earn'],
#  '556': ['acq'],
#  '557': ['earn'],
#  '558': ['acq'],
#  '559': ['acq'],
#  '560': ['earn'],
#  '561': ['acq', 'earn'],
#  '562': ['coffee'],
#  '563': ['acq'],
#  '564': ['acq'],
#  '565': ['money-supply'],
#  '566': ['acq', 'earn'],
#  '567': ['trade', 'interest'],
#  '568': ['acq', 'interest'],
#  '569': ['earn'],
#  '570': ['acq'],
#  '571': ['earn'],
#  '572': ['earn'],
#  '573': ['earn'],
#  '574': ['earn'],
#  '575': ['earn'],
#  '576': ['earn'],
#  '577': ['earn'],
#  '578': ['earn'],
#  '579': ['earn'],
#  '580': ['earn'],
#  '581': ['earn'],
#  '582': ['trade', 'interest'],
#  '583': ['acq'],
#  '584': ['acq'],
#  '585': ['acq', 'earn'],
#  '586': ['earn'],
#  '587': ['acq'],
#  '588': ['earn'],
#  '589': ['acq'],
#  '590': ['money-supply'],
#  '591': ['earn'],
#  '592': ['earn'],
#  '593': ['money-supply'],
#  '594': ['earn'],
#  '595': ['earn'],
#  '596': ['earn'],
#  '597': ['crude'],
#  '598': ['earn'],
#  '599': ['earn'],
#  '600': ['money-supply'],
#  '601': ['earn'],
#  '602': ['acq', 'earn'],
#  '603': ['earn'],
#  '604': ['acq'],
#  '605': ['earn'],
#  '606': ['earn'],
#  '607': ['money-supply'],
#  '608': ['money-supply'],
#  '609': ['acq'],
#  '610': ['earn'],
#  '611': ['money-supply'],
#  '612': ['earn'],
#  '613': ['gold', 'earn'],
#  '614': ['earn'],
#  '615': ['earn'],
#  '616': ['acq'],
#  '617': ['earn'],
#  '618': ['earn'],
#  '619': ['earn'],
#  '620': ['earn'],
#  '621': ['earn'],
#  '622': ['grain', 'corn'],
#  '623': ['acq'],
#  '624': ['earn'],
#  '625': ['earn'],
#  '626': ['gold'],
#  '627': ['acq'],
#  '628': ['trade', 'coffee'],
#  '629': ['crude', 'acq'],
#  '630': ['gold'],
#  '631': ['acq', 'earn'],
#  '632': ['money-supply'],
#  '633': ['earn'],
#  '634': ['grain', 'corn'],
#  '635': ['trade'],
#  '636': ['money-supply'],
#  '637': ['earn'],
#  '638': ['earn'],
#  '639': ['money-supply'],
#  '640': ['earn'],
#  '641': ['acq'],
#  '642': ['earn'],
#  '643': ['money-supply'],
#  '644': ['earn'],
#  '645': ['money-supply', 'interest'],
#  '646': ['earn'],
#  '647': ['acq'],
#  '648': ['money-supply'],
#  '649': ['earn'],
#  '650': ['interest'],
#  '651': ['acq', 'earn'],
#  '652': ['heat', 'fuel'],
#  '653': ['acq'],
#  '654': ['acq', 'earn'],
#  '655': ['acq'],
#  '656': ['tin'],
#  '657': ['acq'],
#  '658': ['acq'],
#  '659': ['acq'],
#  '660': ['acq'],
#  '661': ['acq'],
#  '662': ['acq', 'earn'],
#  '663': ['money-supply'],
#  '664': ['money-supply'],
#  '665': ['money-supply'],
#  '666': ['acq'],
#  '667': ['money-supply', 'acq'],
#  '668': ['crude'],
#  '669': ['gold', 'acq'],
#  '670': ['earn'],
#  '671': ['money-fx', 'acq'],
#  '672': ['acq', 'carcass'],
#  '673': ['money-supply'],
#  '674': ['earn'],
#  '675': ['money-supply'],
#  '676': ['money-fx', 'acq'],
#  '677': ['ship'],
#  '678': ['interest'],
#  '679': ['acq'],
#  '680': ['earn'],
#  '681': ['acq'],
#  '682': ['acq'],
#  '683': ['acq', 'earn'],
#  '684': ['sugar'],
#  '685': ['rubber'],
#  '686': ['earn'],
#  '687': ['earn'],
#  '688': ['tin'],
#  '689': ['earn'],
#  '690': ['earn'],
#  '691': ['earn'],
#  '692': ['earn'],
#  '693': ['earn'],
#  '694': ['oilseed', 'grain', 'soybean', 'wheat', 'corn'],
#  '695': ['earn'],
#  '696': ['earn'],
#  '697': ['gold'],
#  '698': ['earn'],
#  '699': ['earn'],
#  '700': ['earn'],
#  '701': ['earn'],
#  '702': ['earn'],
#  '703': ['acq'],
#  '704': ['crude'],
#  '705': ['earn'],
#  '706': ['acq'],
#  '707': ['earn'],
#  '708': ['crude', 'nat-gas'],
#  '709': ['acq'],
#  '710': ['crude'],
#  '711': ['crude', 'nat-gas'],
#  '712': ['acq'],
#  '713': ['money-supply'],
#  '714': ['acq'],
#  '715': ['earn'],
#  '716': ['interest'],
#  '717': ['earn'],
#  '718': ['trade'],
#  '719': ['acq'],
#  '720': ['money-fx', 'dlr'],
#  '721': ['acq'],
#  '722': ['earn'],
#  '723': ['interest', 'earn'],
#  '724': ['acq'],
#  '725': ['acq'],
#  '726': ['earn'],
#  '727': ['acq'],
#  '728': ['earn'],
#  '729': ['acq'],
#  '730': ['earn', 'acq'],
#  '731': ['earn'],
#  '732': ['acq'],
#  '733': ['acq'],
#  '734': ['earn'],
#  '735': ['acq'],
#  '736': ['acq'],
#  '737': ['acq', 'earn'],
#  '738': ['acq', 'interest'],
#  '739': ['earn'],
#  '740': ['gnp', 'trade'],
#  '741': ['acq'],
#  '742': ['grain', 'wheat'],
#  '743': ['earn'],
#  '744': ['money-fx', 'earn'],
#  '745': ['acq'],
#  '746': ['crude'],
#  '747': ['acq'],
#  '748': ['acq'],
#  '749': ['acq'],
#  '750': ['money-supply'],
#  '751': ['acq'],
#  '752': ['acq'],
#  '753': ['acq', 'earn'],
#  '754': ['coffee'],
#  '755': ['acq'],
#  '756': ['earn'],
#  '757': ['acq'],
#  '758': ['earn'],
#  '759': ['interest'],
#  '760': ['money-supply'],
#  '761': ['money-supply'],
#  '762': ['acq'],
#  '763': ['money-supply', 'acq'],
#  '764': ['acq'],
#  '765': ['money-supply'],
#  '766': ['acq'],
#  '767': ['acq'],
#  '768': ['acq'],
#  '769': ['money-fx', 'dlr'],
#  '770': ['interest', 'earn'],
#  '771': ['money-supply'],
#  '772': ['cpi'],
#  '773': ['earn'],
#  '774': ['earn'],
#  '775': ['jet', 'acq'],
#  '776': ['earn'],
#  '777': ['earn', 'cpi'],
#  '778': ['earn'],
#  '779': ['trade', 'earn'],
#  '780': ['earn'],
#  '781': ['earn'],
#  '782': ['money-supply', 'acq'],
#  '783': ['earn'],
#  '784': ['acq', 'interest'],
#  '785': ['earn'],
#  '786': ['acq'],
#  '787': ['acq'],
#  '788': ['acq'],
#  '789': ['interest'],
#  '790': ['money-supply'],
#  '791': ['crude'],
#  '792': ['money-supply'],
#  '793': ['copper'],
#  '794': ['trade', 'acq'],
#  '795': ['money-supply', 'acq'],
#  '796': ['money-supply'],
#  '797': ['acq'],
#  '798': ['livestock', 'hog'],
#  '799': ['nat-gas', 'earn'],
#  '800': ['copper'],
#  '801': ['acq', 'interest'],
#  '802': ['reserves', 'interest'],
#  '803': ['money-supply', 'earn'],
#  '804': ['crude', 'interest'],
#  '805': ['acq'],
#  '806': ['acq', 'earn'],
#  '807': ['acq', 'earn'],
#  '808': ['money-fx', 'interest'],
#  '809': ['acq'],
#  '810': ['money-supply'],
#  '811': ['earn'],
#  '812': ['interest', 'earn'],
#  '813': ['acq', 'earn'],
#  '814': ['acq'],
#  '815': ['money-supply'],
#  '816': ['copper'],
#  '817': ['earn'],
#  '818': ['earn'],
#  '819': ['acq'],
#  '820': ['acq'],
#  '821': ['crude', 'acq'],
#  '822': ['oat', 'grain'],
#  '823': ['acq'],
#  '824': ['acq', 'earn'],
#  '825': ['acq'],
#  '826': ['money-supply'],
#  '827': ['money-fx', 'interest'],
#  '828': ['earn'],
#  '829': ['propane', 'heat', 'gas'],
#  '830': ['money-supply'],
#  '831': ['money-supply'],
#  '832': ['orange', 'acq'],
#  '833': ['veg-oil', 'soy-oil', 'oilseed', 'soybean'],
#  '834': ['heat'],
#  '835': ['crude'],
#  '836': ['acq'],
#  '837': ['earn'],
#  '838': ['acq'],
#  '839': ['money-supply'],
#  '840': ['acq'],
#  '841': ['interest'],
#  '842': ['coffee'],
#  '843': ['gnp', 'trade'],
#  '844': ['acq'],
#  '845': ['acq', 'earn'],
#  '846': ['earn'],
#  '847': ['acq', 'earn'],
#  '848': ['earn'],
#  '849': ['acq'],
#  '850': ['acq'],
#  '851': ['acq'],
#  '852': ['earn'],
#  '853': ['acq'],
#  '854': ['money-fx', 'trade'],
#  '855': ['grain', 'oat', 'corn', 'oilseed', 'soybean'],
#  '856': ['grain', 'wheat'],
#  '857': ['ship'],
#  '858': ['money-fx', 'acq'],
#  '859': ['earn'],
#  '860': ['money-supply', 'wpi'],
#  '861': ['earn'],
#  '862': ['carcass', 'grain'],
#  '863': ['acq'],
#  '864': ['jobs', 'earn'],
#  '865': ['earn'],
#  '866': ['earn'],
#  '867': ['jobs'],
#  '868': ['earn'],
#  '869': ['money-supply'],
#  '870': ['lei'],
#  '871': ['wheat', 'grain'],
#  '872': ['money-fx', 'yen', 'dlr'],
#  '873': ['crude'],
#  '874': ['grain', 'wheat'],
#  '875': ['coffee'],
#  '876': ['money-supply', 'acq'],
#  '877': ['interest'],
#  '878': ['acq'],
#  '879': ['earn'],
#  '880': ['bop'],
#  '881': ['acq', 'earn'],
#  '882': ['acq'],
#  '883': ['earn'],
#  '884': ['rubber'],
#  '885': ['veg-oil', 'palm-oil'],
#  '886': ['earn'],
#  '887': ['earn'],
#  '888': ['money-fx', 'acq'],
#  '889': ['jobs'],
#  '890': ['bop'],
#  '891': ['money-fx', 'trade'],
#  '892': ['money-supply'],
#  '893': ['trade', 'carcass'],
#  '894': ['trade'],
#  '895': ['jobs'],
#  '896': ['reserves'],
#  '897': ['bop'],
#  '898': ['gnp', 'jobs'],
#  '899': ['earn'],
#  '900': ['interest'],
#  '901': ['interest'],
#  '902': ['earn'],
#  '903': ['money-fx'],
#  '904': ['acq'],
#  '905': ['interest'],
#  '906': ['interest'],
#  '907': ['money-supply'],
#  '908': ['tin'],
#  '909': ['money-fx', 'yen'],
#  '910': ['money-fx', 'interest'],
#  '911': ['money-fx', 'interest'],
#  '912': ['money-supply'],
#  '913': ['money-fx', 'interest'],
#  '914': ['money-fx', 'dlr'],
#  '915': ['money-fx', 'saudriyal'],
#  '916': ['money-fx', 'dlr'],
#  '917': ['money-fx', 'interest'],
#  '918': ['crude'],
#  '919': ['money-fx', 'interest'],
#  '920': ['earn'],
#  '921': ['earn', 'alum'],
#  '922': ['earn'],
#  '923': ['interest'],
#  '924': ['trade'],
#  '925': ['trade'],
#  '926': ['interest', 'money-fx'],
#  '927': ['acq', 'earn'],
#  '928': ['interest', 'earn'],
#  '929': ['cpi'],
#  '930': ['crude'],
#  '931': ['interest'],
#  '932': ['acq'],
#  '933': ['money-fx', 'dlr'],
#  '934': ['grain', 'corn'],
#  '935': ['gold', 'coffee'],
#  '936': ['earn'],
#  '937': ['reserves'],
#  '938': ['earn', 'alum'],
#  '939': ['acq'],
#  '940': ['money-supply'],
#  '941': ['acq'],
#  '942': ['interest', 'money-fx'],
#  '943': ['money-fx', 'interest'],
#  '944': ['veg-oil', 'palm-oil'],
#  '945': ['crude'],
#  '946': ['money-supply'],
#  '947': ['money-fx', 'interest'],
#  '948': ['money-supply'],
#  '949': ['earn'],
#  '950': ['oilseed', 'interest'],
#  '951': ['acq', 'earn'],
#  '952': ['crude'],
#  '953': ['money-fx', 'interest'],
#  '954': ['interest'],
#  '955': ['jobs'],
#  '956': ['money-fx'],
#  '957': ['money-fx', 'acq'],
#  '958': ['earn'],
#  '959': ['grain', 'ship'],
#  '960': ['acq'],
#  '961': ['money-supply', 'acq'],
#  '962': ['money-fx', 'dlr'],
#  '963': ['acq'],
#  '964': ['interest'],
#  '965': ['money-fx', 'trade'],
#  '966': ['interest'],
#  '967': ['acq', 'earn'],
#  '968': ['earn'],
#  '969': ['ship'],
#  '970': ['acq', 'earn'],
#  '971': ['earn'],
#  '972': ['lei'],
#  '973': ['money-supply'],
#  '974': ['lei'],
#  '975': ['reserves', 'money-fx'],
#  '976': ['earn'],
#  '977': ['coffee'],
#  '978': ['acq'],
#  '979': ['acq'],
#  '980': ['interest'],
#  '981': ['earn'],
#  '982': ['acq'],
#  '983': ['earn'],
#  '984': ['earn'],
#  '985': ['acq'],
#  '986': ['earn'],
#  '987': ['interest'],
#  '988': ['earn', 'crude'],
#  '989': ['wpi'],
#  '990': ['acq'],
#  '991': ['trade'],
#  '992': ['money-supply'],
#  '993': ['money-supply'],
#  '994': ['money-supply'],
#  '995': ['earn'],
#  '996': ['acq'],
#  '997': ['money-supply', 'acq'],
#  '998': ['earn'],
#  '999': ['money-fx', 'interest'],
#  '1000': ['acq'],
#  ...}
